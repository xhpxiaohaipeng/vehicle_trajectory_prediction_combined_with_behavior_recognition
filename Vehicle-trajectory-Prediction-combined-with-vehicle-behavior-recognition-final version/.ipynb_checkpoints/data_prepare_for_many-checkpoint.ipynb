# %%
# -*- coding: utf-8 -*-
from io import open
import os.path
from os import path
import random
import numpy as np
import pickle
import pandas as pd
import scipy.signal
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from glob import glob
file_path = np.array(glob('data/data_interactive/train/*'))
class TrajectoryDataset(Dataset):
    def __init__(self, length=40, predict_length=30, file_path=file_path):
        for csv_file in file_path:
            self.csv_file = csv_file
            print(1)
        print(self.csv_file)
        dataS = pd.read_csv(self.csv_file)
#         print(dataS.ID.unique())
        
        for vid in dataS.ID.unique():  # 保证是同车的轨迹,一辆车一辆车地加载数据
            frame_ori = dataS[dataS.ID == vid]  # 访问每一辆车的数据
            frame = frame_ori[
                ['Local_X', 'Local_Y', 'Vel', 'Acc', 'Angle', 'Xl_bot_1', 'Yl_bot_1', 'Distl_bot_1', 'vell_bot_1',
                 'accl_bot_1', 'anglel_bot_1', 'Xl_top_1', 'Yl_top_1', 'Distl_top_1', 'vell_top_1', 'accl_top_1',
                 'anglel_top_1', 'Xc_bot_1', 'Yc_bot_1', 'Distc_bot_1', 'velc_bot_1', 'accc_bot_1', 'anglec_bot_1',
                 'Xc_top_1', 'Yc_top_1', 'Distc_top_1', 'velc_top_1', 'accc_top_1', 'anglec_top_1', 'Xr_bot_1',
                 'Yr_bot_1', 'Distr_bot_1', 'velr_bot_1', 'accr_bot_1', 'angler_bot_1', 'Xr_top_1', 'Yr_top_1',
                 'Distr_top_1', 'velr_top_1', 'accr_top_1', 'angler_top_1']]
            frame = np.asarray(frame) #转化为数组的形式方便处理

            dis = frame[1:, :2] - frame[:-1, :2]
            #转化为float64类型
            dis = dis.astype(np.float64)
            dis = np.sqrt(np.power(dis[:, 0], 2) + np.power(dis[:, 1], 2))
            idx = np.where(dis > 10)
            print("sss",idx[0].all)
            print(idx[0])
            if not (idx[0].all):
                print("discontinuious trajectory")
                continue
file_path_test = np.array(glob('data/data_interactive/valid/prediction_data082703.csv'))
TrajectoryDataset(31, 30,file_path_test)
# Out:
# 1
# data/data_interactive/valid/prediction_data082703.csv
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d72b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2990>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e350>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e350>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e23080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88c10>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88c10>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32300>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32300>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb78736c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32300>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e2b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2990>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e2b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e2b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e2b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2990>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2990>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2990>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# [78]
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ee40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# [56]
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb78736c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# [0]
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768210>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb78736c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb78736c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38d00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e2b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a693f0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38d00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a693f0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7884760>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38d00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d888a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ed00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e2b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb61af1c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680ef30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512e40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a693f0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84080>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82b20>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a693f0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88f80>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc7b0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e16800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82b20>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873df0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7e56670>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82b20>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e38d00>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6d03440>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# [0]
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82c10>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e675d0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82c10>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67cb0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512e40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873ee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82c10>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e381c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6f82c10>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512e40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32170>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe620>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512850>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512e40>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d73a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76a2120>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e673a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7768f30>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7873e90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb75123a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9530>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6e67da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab323a0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7ebe580>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7512ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb7d88bc0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680eee0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb77f9da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84da0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb78736c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e6c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb680e4e0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbaa84ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb76c8710>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb78736c0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb5a3f800>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb72bde90>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb70d7ad0>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cb6fdc940>
# []
# sss <built-in method all of numpy.ndarray object at 0x7f4cbab32b70>
# []

# %%
# -*- coding: utf-8 -*-
from io import open
import os.path
from os import path
import random
import numpy as np
import pickle
import pandas as pd
import scipy.signal
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from glob import glob
file_path = np.array(glob('data/data_interactive/train/*'))

class TrajectoryDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, length=40, predict_length=30, file_path=file_path):
        """
            Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
            on a sample.
            """

        self.X_frames_trajectory = []
        self.Y_frames_trajectory = []
        self.length = length
        self.predict_length = predict_length
        for csv_file in file_path:
            self.csv_file = csv_file
            self.load_data()
        self.normalize_data()

    def __len__(self):
        return len(self.X_frames_trajectory)

    def __getitem__(self, idx):
        single_trajectory_data = self.X_frames_trajectory[idx]
        single_trajectory_label = self.Y_frames_trajectory[idx]
        return (single_trajectory_data, single_trajectory_label)

    def load_data(self):
        dataS = pd.read_csv(self.csv_file)
        dataS = dataS[dataS.Class == 5]
        dataS = dataS[dataS.Static == 0]
        dataS = dataS[dataS.Label != 7]
        dataS = dataS[dataS.ID != -1]
       # print(dataS)
        count_ = []
        #         for i in range(len(dataS['Label'].values)):
        #         if dataS['Label'].values[i] == 0:
        #             Straight += 1
        #         if dataS['Label'].values[i] == 1:
        #             LeftTurn += 1
        #         if dataS['Label'].values[i] == 2:
        #             RightTurn +=
        #         if dataS['Label'].values[i] == 3:
        #             UTurn += 1
        #         if dataS['Label'].values[i] == 4:
        #             LeftChange += 1
        #         if dataS['Label'].values[i] == 5:
        #             RightChange += 1
        #     print(dataS.Label.values)
        #     print("Straight:", Straight, "LeftTurn:", LeftTurn, "RightTurn:", RightTurn, "UTurn:", UTurn, "LeftChange:", LeftChange, "RightChange:", RightChange)
        for vid in dataS.ID.unique():  # 保证是同车的轨迹,一辆车一辆车地加载数据
            frame_ori = dataS[dataS.ID == vid]  # 访问每一辆车的数据
            frame = frame_ori[
                ['Local_X', 'Local_Y', 'Vel', 'Acc', 'Angle', 'Xl_bot_1', 'Yl_bot_1', 'Distl_bot_1', 'vell_bot_1',
                 'accl_bot_1', 'anglel_bot_1', 'Xl_top_1', 'Yl_top_1', 'Distl_top_1', 'vell_top_1', 'accl_top_1',
                 'anglel_top_1', 'Xc_bot_1', 'Yc_bot_1', 'Distc_bot_1', 'velc_bot_1', 'accc_bot_1', 'anglec_bot_1',
                 'Xc_top_1', 'Yc_top_1', 'Distc_top_1', 'velc_top_1', 'accc_top_1', 'anglec_top_1', 'Xr_bot_1',
                 'Yr_bot_1', 'Distr_bot_1', 'velr_bot_1', 'accr_bot_1', 'angler_bot_1', 'Xr_top_1', 'Yr_top_1',
                 'Distr_top_1', 'velr_top_1', 'accr_top_1', 'angler_top_1']]
            frame = np.asarray(frame)
            if len(frame) < 62:
                continue
            dis = frame[1:, :2] - frame[:-1, :2]
            dis = dis.astype(np.float64)
            dis = np.sqrt(np.power(dis[:, 0], 2) + np.power(dis[:, 1], 2))
            idx = np.where(dis > 10)

            if not (idx[0].all):
                print("discontinuious trajectory")
                continue
            frame[:, 0:2] = scipy.signal.savgol_filter(frame[:, 0:2], window_length=21, polyorder=3, axis=0)
            plt.plot(frame[:,0],frame[:,1],c='r',label='trajectory')
            plt.axis('equal')
            plt.legend()
            plt.show()
            All_vels = []
            for i in range(1):
                x_vel = (frame[1:, 0 + i * 5] - frame[:-1, 0 + i * 5]) / 0.1;  # 计算x方向的速度 ,x: 0,5,10,15,20,25,30
                v_avg = (x_vel[1:] + x_vel[:-1]) / 2.0;
                v_begin = [2.0 * x_vel[0] - v_avg[0]];
                v_end = [2.0 * x_vel[-1] - v_avg[-1]];
                velx = (v_begin + v_avg.tolist() + v_end)
                velx = np.array(velx)

                y_vel = (frame[1:, 1 + i * 5] - frame[:-1, 1 + i * 5]) / 0.1;  # 计算y方向的速度,y:1,6,11,16,21,26,31
                vy_avg = (y_vel[1:] + y_vel[:-1]) / 2.0;
                vy1 = [2.0 * y_vel[0] - vy_avg[0]];
                vy_end = [2.0 * y_vel[-1] - vy_avg[-1]];
                vely = (vy1 + vy_avg.tolist() + vy_end)
                vely = np.array(vely)

                if isinstance(All_vels, (list)):  # 判断一个对象是否是一个已知的类型，类似 type()。
                    All_vels = np.vstack((velx, vely))
                else:
                    All_vels = np.vstack((All_vels, velx.reshape(1, -1)))
                    All_vels = np.vstack((All_vels, vely.reshape(1, -1)))
            All_vels = np.transpose(All_vels)
            total_frame_data = np.concatenate((All_vels[:, :2], frame), axis=1)  # 拼接数组
            if (total_frame_data.shape[0] < 62):
                continue
            X = total_frame_data[:-self.predict_length, :]  # 预测30个轨迹点
            Y = total_frame_data[self.predict_length:, :4]
            # print(X.shape,Y.shape)

            count = 0
            for i in range(X.shape[0] - self.length):
                # if random.random() > 0.2:   #-------------------------------
                # continue
                #                 if count > 60:  # 限制每辆车的最大轨迹数
                #                      break
                #  print('X[] shape',X[i:i+100,:].shape)
#                 plt.plot(X[i:i + self.length, 2], X[i:i+self.length, 3], c='r', label='history')
#                 plt.plot(Y[i:i + self.length, 2], Y[i:i+self.length, 3], c='g', label='label') 
#                 plt.axis('equal')
#                 plt.legend()
#                 plt.show()
                self.X_frames_trajectory = self.X_frames_trajectory + [
                    X[i:i + self.length, :]]  # 生成轨迹段,每个轨迹为100个点,所有轨迹集合,组合成输入数据
                self.Y_frames_trajectory = self.Y_frames_trajectory + [Y[i:i + self.length, :]]  # 生成对应的label
                count = count + 1
            count_.append(count)
            print('File:',self.csv_file.split("/")[3],'Vhicle ID:', vid, " Total trajectory point:", total_frame_data.shape[0], 'Total Trajectory:', count)
        print('Sum Trajectory:',np.sum(count_),'Average Trajectory:', np.mean(count_))
        # print(np.array(self.X_frames_trajectory).shape,np.array(self.Y_frames_trajectory).shape)

    def normalize_data(self):  # 标准化每辆车的输入数据
        # 输出轨迹预测数据，进行标准化
        A = [list(x) for x in zip(*(self.X_frames_trajectory))]
        A = np.array(A).astype(np.float64)
        # A = torch.tensor(A)
        A = torch.from_numpy(A)
        #  print(A.shape)
        A = A.view(-1, A.shape[2])
        print('A shape:', A.shape)
        if self.csv_file.split("/")[2] == 'train':
            self.mn = torch.mean(A, dim=0)
            # print(self.mn.shape)
            self.range = (torch.max(A, dim=0).values - torch.min(A, dim=0).values) / 2.0
            self.range = torch.ones(self.range.shape, dtype=torch.double)
            # print(self.range.shape)
            self.std = torch.std(A, dim=0)
            #   print(self.std.shape)
            std = self.std.numpy()    
            mn = self.mn.numpy() 
            rg = self.range.numpy()    
            np.savetxt("std.txt", std)
            np.savetxt("mean.txt", mn)
            np.savetxt("rg.txt", rg)
        else:
            mn= torch.from_numpy(np.loadtxt('mean.txt'))
            std = torch.from_numpy(np.loadtxt('std.txt'))
            rg = torch.from_numpy(np.loadtxt('rg.txt'))
            self.mn = mn
            self.range = rg
            self.std = std
        self.X_frames_trajectory = [
            (torch.from_numpy(np.array(item).astype(np.float64)) - self.mn) / (self.std * self.range) for item in
            self.X_frames_trajectory]
        self.Y_frames_trajectory = [
            (torch.from_numpy(np.array(item).astype(np.float64)) - self.mn[:4]) / (self.std[:4] * self.range[:4]) for
            item in self.Y_frames_trajectory]


def get_dataloader(BatchSize=64, length=40, predict_length=30,file_path = np.array(glob('data/data_interactive/train/*')),daset = 'train'):
    '''
    return torch.util.data.Dataloader for train,test and validation
    '''
    # load dataset
    if path.exists("pickle/dataset_traj_{}_0804_43_4_{}_{}.pickle".format(daset,predict_length, length)):
        with open('pickle/dataset_traj_{}_0804_43_4_{}_{}.pickle'.format(daset,predict_length, length), 'rb') as data:
            dataset = pickle.load(data)
    else:
        dataset = TrajectoryDataset(length, predict_length,file_path)
        with open('pickle/dataset_traj_{}_0804_43_4_{}_{}.pickle'.format(daset,predict_length, length), 'wb') as output:
            pickle.dump(dataset, output)
    # split dataset into train test and validation 8:1:1
    length_traj = dataset.__len__()
    #num_train_traj = (int)(length_traj * 0.8)
   # num_test_traj = (int)(length_traj * 0.9) - num_train_traj
    #num_validation_traj = (int)(length_traj - num_test_traj - num_train_traj)

   # train_traj, test_traj, validation_traj = torch.utils.data.random_split(dataset, [num_train_traj, num_test_traj,
                                                                                    # num_validation_traj])

    train_loader_traj = DataLoader(dataset, batch_size=BatchSize, shuffle=True)
    #test_loader_traj = DataLoader(test_traj, batch_size=BatchSize, shuffle=True)
   # validation_loader_traj = DataLoader(validation_traj, batch_size=BatchSize, shuffle=True)
    iters = iter(train_loader_traj)
    x_trajectory, y_trajectory = next(iters)
    print("*" * 100)
    if daset == 'train':
        print('训练轨迹轨迹条数：', length_traj)
    if daset == 'valid':
        print('验证轨迹轨迹条数：', length_traj)
    if daset == 'test':
        print('测试轨迹轨迹条数：', length_traj)
    print('---轨迹输入数据结构：', x_trajectory.shape, '---轨迹输出数据结构：', y_trajectory.shape)
    print('---轨迹长度：', length, '---预测轨迹长度：', predict_length)
    return (train_loader_traj, dataset)

# %%
file_path_test = np.array(glob('data/data_interactive/valid/prediction_data082703.csv'))
TrajectoryDataset(31, 30,file_path_test)
# Out:
# File: prediction_data082703.csv Vhicle ID: 784.0  Total trajectory point: 83 Total Trajectory: 22
# File: prediction_data082703.csv Vhicle ID: 788.0  Total trajectory point: 75 Total Trajectory: 14
# File: prediction_data082703.csv Vhicle ID: 789.0  Total trajectory point: 80 Total Trajectory: 19
# File: prediction_data082703.csv Vhicle ID: 792.0  Total trajectory point: 65 Total Trajectory: 4
# File: prediction_data082703.csv Vhicle ID: 794.0  Total trajectory point: 70 Total Trajectory: 9
# File: prediction_data082703.csv Vhicle ID: 795.0  Total trajectory point: 91 Total Trajectory: 30
# File: prediction_data082703.csv Vhicle ID: 796.0  Total trajectory point: 72 Total Trajectory: 11
# File: prediction_data082703.csv Vhicle ID: 824.0  Total trajectory point: 64 Total Trajectory: 3
# File: prediction_data082703.csv Vhicle ID: 832.0  Total trajectory point: 203 Total Trajectory: 142
# File: prediction_data082703.csv Vhicle ID: 848.0  Total trajectory point: 103 Total Trajectory: 42
# File: prediction_data082703.csv Vhicle ID: 850.0  Total trajectory point: 393 Total Trajectory: 332
# File: prediction_data082703.csv Vhicle ID: 968.0  Total trajectory point: 64 Total Trajectory: 3
# File: prediction_data082703.csv Vhicle ID: 969.0  Total trajectory point: 73 Total Trajectory: 12
# File: prediction_data082703.csv Vhicle ID: 970.0  Total trajectory point: 76 Total Trajectory: 15
# File: prediction_data082703.csv Vhicle ID: 976.0  Total trajectory point: 72 Total Trajectory: 11
# File: prediction_data082703.csv Vhicle ID: 1002.0  Total trajectory point: 84 Total Trajectory: 23
# File: prediction_data082703.csv Vhicle ID: 1011.0  Total trajectory point: 95 Total Trajectory: 34
# File: prediction_data082703.csv Vhicle ID: 1049.0  Total trajectory point: 872 Total Trajectory: 811
# File: prediction_data082703.csv Vhicle ID: 1066.0  Total trajectory point: 75 Total Trajectory: 14
# File: prediction_data082703.csv Vhicle ID: 1069.0  Total trajectory point: 139 Total Trajectory: 78
# File: prediction_data082703.csv Vhicle ID: 1081.0  Total trajectory point: 86 Total Trajectory: 25
# File: prediction_data082703.csv Vhicle ID: 1104.0  Total trajectory point: 80 Total Trajectory: 19
# File: prediction_data082703.csv Vhicle ID: 1114.0  Total trajectory point: 140 Total Trajectory: 79
# File: prediction_data082703.csv Vhicle ID: 1121.0  Total trajectory point: 132 Total Trajectory: 71
# File: prediction_data082703.csv Vhicle ID: 1128.0  Total trajectory point: 166 Total Trajectory: 105
# File: prediction_data082703.csv Vhicle ID: 1143.0  Total trajectory point: 70 Total Trajectory: 9
# File: prediction_data082703.csv Vhicle ID: 1152.0  Total trajectory point: 127 Total Trajectory: 66
# File: prediction_data082703.csv Vhicle ID: 1175.0  Total trajectory point: 153 Total Trajectory: 92
# File: prediction_data082703.csv Vhicle ID: 1182.0  Total trajectory point: 352 Total Trajectory: 291
# File: prediction_data082703.csv Vhicle ID: 1185.0  Total trajectory point: 100 Total Trajectory: 39
# File: prediction_data082703.csv Vhicle ID: 1190.0  Total trajectory point: 101 Total Trajectory: 40
# File: prediction_data082703.csv Vhicle ID: 1216.0  Total trajectory point: 99 Total Trajectory: 38
# File: prediction_data082703.csv Vhicle ID: 1383.0  Total trajectory point: 111 Total Trajectory: 50
# File: prediction_data082703.csv Vhicle ID: 1424.0  Total trajectory point: 95 Total Trajectory: 34
# File: prediction_data082703.csv Vhicle ID: 1430.0  Total trajectory point: 134 Total Trajectory: 73
# File: prediction_data082703.csv Vhicle ID: 1440.0  Total trajectory point: 89 Total Trajectory: 28
# File: prediction_data082703.csv Vhicle ID: 1441.0  Total trajectory point: 101 Total Trajectory: 40
# File: prediction_data082703.csv Vhicle ID: 1452.0  Total trajectory point: 118 Total Trajectory: 57
# File: prediction_data082703.csv Vhicle ID: 1459.0  Total trajectory point: 102 Total Trajectory: 41
# File: prediction_data082703.csv Vhicle ID: 1463.0  Total trajectory point: 87 Total Trajectory: 26
# File: prediction_data082703.csv Vhicle ID: 1471.0  Total trajectory point: 97 Total Trajectory: 36
# File: prediction_data082703.csv Vhicle ID: 1487.0  Total trajectory point: 90 Total Trajectory: 29
# File: prediction_data082703.csv Vhicle ID: 1488.0  Total trajectory point: 83 Total Trajectory: 22
# File: prediction_data082703.csv Vhicle ID: 1497.0  Total trajectory point: 83 Total Trajectory: 22
# File: prediction_data082703.csv Vhicle ID: 1509.0  Total trajectory point: 73 Total Trajectory: 12
# File: prediction_data082703.csv Vhicle ID: 1511.0  Total trajectory point: 74 Total Trajectory: 13
# File: prediction_data082703.csv Vhicle ID: 1529.0  Total trajectory point: 68 Total Trajectory: 7
# File: prediction_data082703.csv Vhicle ID: 1550.0  Total trajectory point: 86 Total Trajectory: 25
# File: prediction_data082703.csv Vhicle ID: 1566.0  Total trajectory point: 76 Total Trajectory: 15
# File: prediction_data082703.csv Vhicle ID: 1568.0  Total trajectory point: 80 Total Trajectory: 19
# File: prediction_data082703.csv Vhicle ID: 1573.0  Total trajectory point: 95 Total Trajectory: 34
# File: prediction_data082703.csv Vhicle ID: 1600.0  Total trajectory point: 66 Total Trajectory: 5
# File: prediction_data082703.csv Vhicle ID: 1601.0  Total trajectory point: 62 Total Trajectory: 1
# File: prediction_data082703.csv Vhicle ID: 1604.0  Total trajectory point: 71 Total Trajectory: 10
# File: prediction_data082703.csv Vhicle ID: 1639.0  Total trajectory point: 103 Total Trajectory: 42
# File: prediction_data082703.csv Vhicle ID: 1689.0  Total trajectory point: 93 Total Trajectory: 32
# File: prediction_data082703.csv Vhicle ID: 1690.0  Total trajectory point: 111 Total Trajectory: 50
# File: prediction_data082703.csv Vhicle ID: 1697.0  Total trajectory point: 93 Total Trajectory: 32
# File: prediction_data082703.csv Vhicle ID: 1726.0  Total trajectory point: 205 Total Trajectory: 144
# File: prediction_data082703.csv Vhicle ID: 1737.0  Total trajectory point: 80 Total Trajectory: 19
# File: prediction_data082703.csv Vhicle ID: 1745.0  Total trajectory point: 82 Total Trajectory: 21
# File: prediction_data082703.csv Vhicle ID: 1765.0  Total trajectory point: 92 Total Trajectory: 31
# File: prediction_data082703.csv Vhicle ID: 1770.0  Total trajectory point: 104 Total Trajectory: 43
# File: prediction_data082703.csv Vhicle ID: 1814.0  Total trajectory point: 81 Total Trajectory: 20
# File: prediction_data082703.csv Vhicle ID: 1835.0  Total trajectory point: 67 Total Trajectory: 6
# File: prediction_data082703.csv Vhicle ID: 1864.0  Total trajectory point: 70 Total Trajectory: 9
# File: prediction_data082703.csv Vhicle ID: 1901.0  Total trajectory point: 82 Total Trajectory: 21
# File: prediction_data082703.csv Vhicle ID: 1908.0  Total trajectory point: 79 Total Trajectory: 18
# File: prediction_data082703.csv Vhicle ID: 1912.0  Total trajectory point: 281 Total Trajectory: 220
# File: prediction_data082703.csv Vhicle ID: 1927.0  Total trajectory point: 71 Total Trajectory: 10
# File: prediction_data082703.csv Vhicle ID: 1935.0  Total trajectory point: 70 Total Trajectory: 9
# File: prediction_data082703.csv Vhicle ID: 1944.0  Total trajectory point: 93 Total Trajectory: 32
# File: prediction_data082703.csv Vhicle ID: 1973.0  Total trajectory point: 87 Total Trajectory: 26
# File: prediction_data082703.csv Vhicle ID: 1974.0  Total trajectory point: 910 Total Trajectory: 849
# File: prediction_data082703.csv Vhicle ID: 2031.0  Total trajectory point: 84 Total Trajectory: 23
# File: prediction_data082703.csv Vhicle ID: 2117.0  Total trajectory point: 117 Total Trajectory: 56
# File: prediction_data082703.csv Vhicle ID: 2188.0  Total trajectory point: 85 Total Trajectory: 24
# File: prediction_data082703.csv Vhicle ID: 2190.0  Total trajectory point: 89 Total Trajectory: 28
# File: prediction_data082703.csv Vhicle ID: 2201.0  Total trajectory point: 69 Total Trajectory: 8
# File: prediction_data082703.csv Vhicle ID: 2203.0  Total trajectory point: 87 Total Trajectory: 26
# File: prediction_data082703.csv Vhicle ID: 2204.0  Total trajectory point: 69 Total Trajectory: 8
# File: prediction_data082703.csv Vhicle ID: 2205.0  Total trajectory point: 76 Total Trajectory: 15
# File: prediction_data082703.csv Vhicle ID: 2214.0  Total trajectory point: 93 Total Trajectory: 32
# File: prediction_data082703.csv Vhicle ID: 2226.0  Total trajectory point: 80 Total Trajectory: 19
# File: prediction_data082703.csv Vhicle ID: 2227.0  Total trajectory point: 200 Total Trajectory: 139
# File: prediction_data082703.csv Vhicle ID: 2250.0  Total trajectory point: 72 Total Trajectory: 11
# File: prediction_data082703.csv Vhicle ID: 2253.0  Total trajectory point: 89 Total Trajectory: 28
# File: prediction_data082703.csv Vhicle ID: 2254.0  Total trajectory point: 276 Total Trajectory: 215
# File: prediction_data082703.csv Vhicle ID: 2261.0  Total trajectory point: 64 Total Trajectory: 3
# File: prediction_data082703.csv Vhicle ID: 2262.0  Total trajectory point: 85 Total Trajectory: 24
# File: prediction_data082703.csv Vhicle ID: 2340.0  Total trajectory point: 63 Total Trajectory: 2
# File: prediction_data082703.csv Vhicle ID: 2407.0  Total trajectory point: 1191 Total Trajectory: 1130
# File: prediction_data082703.csv Vhicle ID: 2473.0  Total trajectory point: 101 Total Trajectory: 40
# File: prediction_data082703.csv Vhicle ID: 2536.0  Total trajectory point: 101 Total Trajectory: 40
# File: prediction_data082703.csv Vhicle ID: 2890.0  Total trajectory point: 103 Total Trajectory: 42
# File: prediction_data082703.csv Vhicle ID: 2900.0  Total trajectory point: 72 Total Trajectory: 11
# File: prediction_data082703.csv Vhicle ID: 3045.0  Total trajectory point: 98 Total Trajectory: 37
# File: prediction_data082703.csv Vhicle ID: 3182.0  Total trajectory point: 129 Total Trajectory: 68
# Sum Trajectory: 14189 Average Trajectory: 85.9939393939394
# A shape: torch.Size([439859, 43])
