# %%
# -*- coding: utf-8 -*-

from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import time
import math
import random
import pandas as pd
import scipy.signal
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
import torch.distributions as dist
from trajectory_dataPrepare50 import *

torch.manual_seed(0)

MAX_LENGTH = 100
torch.cuda.set_device(1)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print('ok')
length = 100
predict_length=30
Training_generator, Test, Valid, WholeSet= get_dataloader(128,length,predict_length)

class NNPred(nn.Module):
    def __init__(self, input_size, output_size,hidden_size,batch_size, dropout=0.1):
        super(NNPred, self).__init__()
        
        self.batch_size = batch_size
        self.hidden_size = hidden_size
        self.num_layers = 2

        self.in2lstm = nn.Linear(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size,num_layers=self.num_layers,bidirectional=False,batch_first=True,dropout =dropout)
        self.in2bilstm = nn.Linear(input_size, hidden_size)
        self.bilstm = nn.LSTM(hidden_size, hidden_size//2,num_layers=self.num_layers,bidirectional=True,batch_first=True,dropout =dropout)
    
        self.fc0 = nn.Linear(hidden_size,hidden_size*2)
        self.fc1 = nn.Linear(hidden_size*2,int(hidden_size/2))
        self.in2out = nn.Linear(input_size, int(hidden_size/2))
        self.fc2 = nn.Linear(int(hidden_size/2) ,output_size)
        self.tanh = nn.Tanh()
        
    def forward(self, input):
        #input = tensor shape[batchsize, len, num_features]
        bilstm_out,_= self.bilstm(self.in2bilstm(input))
        lstm_out,_= self.lstm(self.in2lstm(input))
        out = self.tanh(self.fc0(lstm_out+bilstm_out))
        out = self.tanh(self.fc1(out))
        out =  out + self.in2out(input)
        output = self.fc2(out)# range [0 -> 1 ]
        return output
# Out:
# ok
# ****************************** ——-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-—— ******************************
# ---输入数据结构： torch.Size([128, 100, 50]) ---输出数据结构： torch.Size([128, 100, 4])
# ---轨迹长度： 100 ---预测轨迹长度： 30

# %%
import  torch
import numpy as np
f = [[[2,3],[4,5],[4,6]]]
d = [[[1,1,1]]]
print(np.array(f).shape,np.array(d).shape)
g = torch.tensor(d).bmm(torch.tensor(f))
print(g)
# Out:
# (1, 3, 2) (1, 1, 3)
# tensor([[[10, 14]]])

# %%
def trainIters(encoder, epoches,learning_rate=0.0001,print_every=7):
    start = time.time()
    # print_loss_total = 0  # Reset every print_every
 #  plot_loss_total = 0  # Reset every plot_every
    #criterion = nn.SmoothL1Loss()
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(encoder_optimizer,mode='min',factor=0.1,
patience=200,verbose=True,threshold=0.0001,threshold_mode='rel',cooldown=0,min_lr=0,eps=1e-015)
    #criterion = nn.MSELoss(reduction='sum')
    criterion = nn.MSELoss()
    loss_min = np.inf
    train_losses =[]
    valid_losses =[]
    for e in range(1, epoches + 1):
        train_loss = []
        for batch_i,(local_batch, local_labels) in enumerate(Training_generator):
            #if local_batch.shape[0]!=BatchSize:
             #   continue
            encoder.zero_grad()
            local_batch = local_batch.to(device)
            local_labels = local_labels.to(device)
            
            predY = encoder(local_batch)
            loss = criterion(predY,local_labels).to(device)
            loss.backward()
            encoder_optimizer.step()
            train_loss.append(loss.item())
            if batch_i % print_every == 0:     
                valid_loss = []
                encoder.eval()
                for x,y in Valid:
                    x,y = x.to(device),y.to(device)
                    predict = encoder(x)
                    loss_valid = criterion(predict,y)
                    valid_loss.append(loss_valid.item())
                encoder.train()
                train_loss_mean = np.mean(train_loss)
                valid_loss_mean = np.mean(valid_loss)
                train_losses.append(train_loss_mean)
                valid_losses.append(valid_loss_mean)
                scheduler.step(valid_loss_mean)
                print("Epoch:{}/{},Step:{}/{}".format(e,epoches,batch_i,len(Training_generator)),
                  "Train_Loss:{},Valid_Loss: {}".format(train_loss_mean,valid_loss_mean))
                if valid_loss_mean < loss_min :                             
                    print("valid_loss decrease!!!save the model.")
                    loss_min = valid_loss_mean
                    torch.save(encoder.state_dict(),'model/trajectory_predict_improve_50_4_30.pt')
                torch.save(encoder.state_dict(),'model/trajectory_predict_improve_50_4_30_each.pt')
    plt.plot(train_losses,color = 'r',label = 'Train_Loss')
    plt.plot(valid_losses,color = 'g',label = 'Valid_Loss')
    plt.title('Loss_Trend')
    plt.xlabel('Epoches')
    plt.ylabel('Loss')
    #plt.title('损失变化')
    #plt.xlabel('迭代次数')
    #plt.ylabel('损失大小')
    plt.legend()
    plt.rcParams['font.sans-serif'] = ['SimHei']
    plt.savefig('image/trajectory_loss_improve_50_4_30.svg',dpi=600)
    plt.savefig('image/trajectory_loss_improve_50_4_30.png',dpi=600)

# %%
train_iter = iter(Training_generator)
x, y = train_iter.next()
print(x.shape,y.shape)
hidden_size = 256
Prednet = NNPred(x.shape[2], y.shape[2],hidden_size, x.shape[0])
# Out:
# torch.Size([128, 100, 50]) torch.Size([128, 100, 4])

# %%
# #print(device)

TRAN_TAG = True
if TRAN_TAG:
    if path.exists("model/trajectory_predict_improve_50_4_30.pt"):
        Prednet.load_state_dict(torch.load('model/trajectory_predict_improve_50_4_30.pt'))
    Prednet = Prednet.double()
    Prednet = Prednet.to(device)
    trainIters(Prednet, 1000,0.0001,20)
   # torch.save(Prednet.state_dict(), 'trajectory_predict.pt')
   # showPlot(plot_lo0sses)
else:
    Prednet.load_state_dict(torch.load('model/trajectory_predict_improve_50_4_30.pt'))
    Prednet = Prednet.double()
    Prednet = Prednet.to(device)
    Prednet.eval()
    Eval_net(Prednet)
# Out:
# Epoch:1/1000,Step:0/95 Train_Loss:1.2309140142913284,Valid_Loss: 1.1225504669449693
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:20/95 Train_Loss:0.9599391056716785,Valid_Loss: 0.7316232999497393
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:40/95 Train_Loss:0.7516163658175392,Valid_Loss: 0.41213629757957243
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:60/95 Train_Loss:0.626312018989487,Valid_Loss: 0.31985059597428583
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:80/95 Train_Loss:0.5459302986567439,Valid_Loss: 0.2766946526370057
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:0/95 Train_Loss:0.30663047510278774,Valid_Loss: 0.2575655106248271
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:20/95 Train_Loss:0.26347994690531085,Valid_Loss: 0.23789875196738275
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:40/95 Train_Loss:0.24821104686639048,Valid_Loss: 0.22459477679601453
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:60/95 Train_Loss:0.2355488285227279,Valid_Loss: 0.2037048343022466
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:80/95 Train_Loss:0.2249883378242213,Valid_Loss: 0.17004477947333213
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:0/95 Train_Loss:0.14632263471091547,Valid_Loss: 0.1448746414789501
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:20/95 Train_Loss:0.129916781264477,Valid_Loss: 0.12169230291842136
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:40/95 Train_Loss:0.12254612532177887,Valid_Loss: 0.10440861732405117
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:60/95 Train_Loss:0.11367907190016667,Valid_Loss: 0.09378488580366039
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:80/95 Train_Loss:0.10930665573782161,Valid_Loss: 0.08633237237188021
# valid_loss decrease!!!save the model.
# Epoch:4/1000,Step:0/95 Train_Loss:0.0826841657742679,Valid_Loss: 0.08194829695007431
# valid_loss decrease!!!save the model.
# Epoch:4/1000,Step:20/95 Train_Loss:0.07834218608893033,Valid_Loss: 0.07829682780906502
# valid_loss decrease!!!save the model.
# Epoch:4/1000,Step:40/95 Train_Loss:0.0780505838780939,Valid_Loss: 0.07272350371110907
# valid_loss decrease!!!save the model.
# Epoch:4/1000,Step:60/95 Train_Loss:0.07662571310060397,Valid_Loss: 0.06876758735843336
# valid_loss decrease!!!save the model.
# Epoch:4/1000,Step:80/95 Train_Loss:0.07494859780860945,Valid_Loss: 0.06602946762926573
# valid_loss decrease!!!save the model.
# Epoch:5/1000,Step:0/95 Train_Loss:0.05402437841394543,Valid_Loss: 0.06272682749259004
# valid_loss decrease!!!save the model.
# Epoch:5/1000,Step:20/95 Train_Loss:0.06373679237378774,Valid_Loss: 0.05998901501410566
# valid_loss decrease!!!save the model.
# Epoch:5/1000,Step:40/95 Train_Loss:0.06176370310404362,Valid_Loss: 0.058967442971620355
# valid_loss decrease!!!save the model.
# Epoch:5/1000,Step:60/95 Train_Loss:0.06084034883431342,Valid_Loss: 0.055549940913647296
# valid_loss decrease!!!save the model.
# Epoch:5/1000,Step:80/95 Train_Loss:0.060309639926853065,Valid_Loss: 0.05448919580476684
# valid_loss decrease!!!save the model.
# Epoch:6/1000,Step:0/95 Train_Loss:0.0609891214479851,Valid_Loss: 0.05197081440198752
# valid_loss decrease!!!save the model.
# Epoch:6/1000,Step:20/95 Train_Loss:0.05264140979807826,Valid_Loss: 0.05132215772331381
# valid_loss decrease!!!save the model.
# Epoch:6/1000,Step:40/95 Train_Loss:0.051757132317992206,Valid_Loss: 0.0489513235147877
# valid_loss decrease!!!save the model.
# Epoch:6/1000,Step:60/95 Train_Loss:0.05154731997816705,Valid_Loss: 0.04700351147165243
# valid_loss decrease!!!save the model.
# Epoch:6/1000,Step:80/95 Train_Loss:0.05082733143866803,Valid_Loss: 0.04672922950424133
# valid_loss decrease!!!save the model.
# Epoch:7/1000,Step:0/95 Train_Loss:0.0469116434318969,Valid_Loss: 0.04520625007799563
# valid_loss decrease!!!save the model.
# Epoch:7/1000,Step:20/95 Train_Loss:0.04622423724267411,Valid_Loss: 0.04630231737937603
# Epoch:7/1000,Step:40/95 Train_Loss:0.046260821860259184,Valid_Loss: 0.04341005893891746
# valid_loss decrease!!!save the model.
# Epoch:7/1000,Step:60/95 Train_Loss:0.04558675481997172,Valid_Loss: 0.04270474808974408
# valid_loss decrease!!!save the model.
# Epoch:7/1000,Step:80/95 Train_Loss:0.044990319255477695,Valid_Loss: 0.04261760473675841
# valid_loss decrease!!!save the model.
# Epoch:8/1000,Step:0/95 Train_Loss:0.03881746472137971,Valid_Loss: 0.04153377629618527
# valid_loss decrease!!!save the model.
# Epoch:8/1000,Step:20/95 Train_Loss:0.039014954466355084,Valid_Loss: 0.04034477411362277
# valid_loss decrease!!!save the model.
# Epoch:8/1000,Step:40/95 Train_Loss:0.04032386062453753,Valid_Loss: 0.03965957192772996
# valid_loss decrease!!!save the model.
# Epoch:8/1000,Step:60/95 Train_Loss:0.04071334954366748,Valid_Loss: 0.038713272821381976
# valid_loss decrease!!!save the model.
# Epoch:8/1000,Step:80/95 Train_Loss:0.0408029832681239,Valid_Loss: 0.038910738067687446
# Epoch:9/1000,Step:0/95 Train_Loss:0.033138256120064484,Valid_Loss: 0.03871386885749741
# Epoch:9/1000,Step:20/95 Train_Loss:0.037356274827236295,Valid_Loss: 0.03874376049376603
# Epoch:9/1000,Step:40/95 Train_Loss:0.038672125552579914,Valid_Loss: 0.036924735735479844
# valid_loss decrease!!!save the model.
# Epoch:9/1000,Step:60/95 Train_Loss:0.03830739267485022,Valid_Loss: 0.03601826195415524
# valid_loss decrease!!!save the model.
# Epoch:9/1000,Step:80/95 Train_Loss:0.03792164067517473,Valid_Loss: 0.03616765392023806
# Epoch:10/1000,Step:0/95 Train_Loss:0.041822188480234675,Valid_Loss: 0.036017276861048934
# valid_loss decrease!!!save the model.
# Epoch:10/1000,Step:20/95 Train_Loss:0.03443237064635315,Valid_Loss: 0.03498241222473511
# valid_loss decrease!!!save the model.
# Epoch:10/1000,Step:40/95 Train_Loss:0.03548132415004899,Valid_Loss: 0.034813158184206536
# valid_loss decrease!!!save the model.
# Epoch:10/1000,Step:60/95 Train_Loss:0.0357513950479669,Valid_Loss: 0.0341695345042817
# valid_loss decrease!!!save the model.

# %%
def calcu_XY(predY):
    #input: [batchsize len features]; features:[velx,vely,x,y]
    '''
    deltaY = v0*delta_t + 0.5* a *delta_t^2
    a = (v - v0)/delta_t
    vo
    '''
    vels = predY[:,:,0:2]
    rst_xy = np.zeros(predY[:,:,0:2].shape)
    rst_xy[:,:-predict_length,:] = predY[:,:-predict_length,2:4]
    delta_t = 0.1
   
    for i in range(predict_length):
        a = (vels[:,-(predict_length-i),:] - vels[:,-(predict_length+1-i),:])/delta_t
        delta_xy = vels[:,-(predict_length-i),:]*vels[:,-(predict_length-i),:]-vels[:,-(predict_length+1-i),:]*vels[:,-(predict_length+1-i),:]
        delta_xy = delta_xy/(2*a)
        rst_xy[:,-(predict_length-i),:] = rst_xy[:,-(predict_length+1-i),:] + delta_xy
    """
    for i in range(1,100):
        a = (vels[:,i,:] - vels[:,i-1,:])/delta_t
        delta_xy = vels[:,i,:]*vels[:,i-1,:]-vels[:,i-1,:]*vels[:,i-1,:]
        delta_xy = delta_xy/(2*a)
        rst_xy[:,i,:] = rst_xy[:,i-1,:] + delta_xy
       """
    t = rst_xy-predY[:,:,2:4]
    #print(rst_xy)
    #print(t[1,:,:])
    return rst_xy

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.show()

# %%
def Eval_net(encoder):
    n_trajectory_batch = 0
    loss = []
    for local_batch, local_labels in Test:
        n_trajectory_batch = n_trajectory_batch + 1
        criterion = nn.MSELoss()
        local_batch = local_batch.to(device)
        local_labels = local_labels.to(device)
        predY = encoder(local_batch)
        #print(WholeSet.std.repeat(BatchSize,100,1).shape)
        test_loss = criterion(predY,local_labels)
        loss.append(test_loss.item())
        std = WholeSet.std.repeat(local_batch.shape[0],x.shape[1],1)
        std = std[:,:,:4].to(device)
        mn = WholeSet.mn.repeat(local_batch.shape[0],x.shape[1],1)
        mn = mn[:,:,:4].to(device)
        rg = WholeSet.range.repeat(local_batch.shape[0],x.shape[1],1)
        rg = rg[:,:,:4].to(device)
        predY = (predY*(rg*std)+mn).detach().cpu()
        pY = np.array(predY )
        pY =  scipy.signal.savgol_filter(pY, window_length=x.shape[1]-11, polyorder=3,axis=1)
        local_labels = (local_labels*(rg*std)+mn).detach().cpu()
        Y = np.array(local_labels)
        pY[:,:-predict_length,:] = Y[:,:-predict_length,:]
        rst_xy = calcu_XY(pY)
        if n_trajectory_batch > 20:
            break
        for i in range(1):
            #plt.figure(i)
            #plt.xlim(0,80)
            #plt.ylim(0,2000)
            #plt.subplot(4,5,n_trajectory_batch)
            plt.plot(pY[i,:,2],pY[i,:,3],'r',label='prediction')
            plt.plot(Y[i,:,2],Y[i,:,3],'g',label='actual')
            plt.plot(rst_xy[i,:,0],rst_xy[i,:,1],'b',label='rst_xy')
            plt.legend()
        plt.show()
        print('Test loss:',test_loss.item())
    print('average loss:',np.mean(loss))

# %%
hidden_size = 256
Prednet = NNPred(x.shape[2], y.shape[2],hidden_size, x.shape[0])
Prednet.load_state_dict(torch.load('model/trajectory_predict_improve_30.pt'))
Prednet = Prednet.double()
Prednet = Prednet.to(device)
Prednet.eval()
Eval_net(Prednet)
# Out:
# Test loss: 0.02708426899718641
# Test loss: 0.030240294845124617
# Test loss: 0.04335406787531988
# Test loss: 0.024621885418236476
# Test loss: 0.038909643722045105
# Test loss: 0.05100238260498404
# Test loss: 0.0836911867893576
# Test loss: 0.04353893537034155
# Test loss: 0.03978477117072577
# Test loss: 0.1398446737658813
# Test loss: 0.7858812098893719
# Test loss: 0.026948171316212473
# Test loss: 0.03016763298335919
# Test loss: 0.05429624902653936
# Test loss: 0.02382196587402574
# Test loss: 0.04413587984029481
# Test loss: 0.7478240124796535
# Test loss: 0.105728309032702
# Test loss: 0.05589415067465371
# Test loss: 0.037779978723059195
# average loss: 0.11776468722965903

# %%
def predict(model,test_load,n):
    test = iter(test_load)
    x,y =  test.next()
    x,y = x.to(device),y.to(device)
    predY = model(x)
    criterion = nn.MSELoss()
    test_loss = criterion(predY,y)
    std = WholeSet.std.repeat(x.shape[0],x.shape[1],1)
    std = std[:,:,:4].to(device)
    mn = WholeSet.mn.repeat(x.shape[0],x.shape[1],1)
    mn = mn[:,:,:4].to(device)
    rg = WholeSet.range.repeat(x.shape[0],x.shape[1],1)
    rg = rg[:,:,:4].to(device)
    predY = (predY*(rg*std)+mn).detach().cpu()
    pY = np.array(predY)
    pY =  scipy.signal.savgol_filter(pY, window_length=x.shape[1]-11, polyorder=3,axis=1)
    local_labels = (y*(rg*std)+mn).detach().cpu()
    Y = np.array(local_labels)
    pY[:,:-predict_length,:] = Y[:,:-predict_length,:]
    rst_xy = calcu_XY(pY)
    #rst_xy =  scipy.signal.savgol_filter(rst_xy, window_length=31, polyorder=3,axis=1)
    #rst_xy[:,-30:-1,:]=  scipy.signal.savgol_filter(rst_xy[:,-30:-1,:], window_length=51, polyorder=3,axis=0)
    plt.plot(rst_xy[:n,:,0][0],rst_xy[:n,:,1][0],'b',label="rst_xy")
    plt.plot(pY[:n,:,2][0],pY[:n,:,3][0],'r',label='prediction')
    plt.plot(Y[:n,:,2][0],Y[:n,:,3][0],'g',label='actual')
    plt.legend()
    print("Test Loss:",test_loss.item())

# %%
hidden_size = 256
Prednet = NNPred(x.shape[2], y.shape[2],hidden_size, x.shape[0])
Prednet.load_state_dict(torch.load('model/trajectory_predict_improve_30.pt'))
Prednet = Prednet.double()
Prednet = Prednet.to(device)
Prednet.eval()
predict(Prednet,Test,1)
# Out:
# Test Loss: 0.026763107015284476

# %%
test_iter = iter(Test)
x, y = test_iter.next()
print(x.shape)
x,y = x.to(device),y.to(device)
x = x[0][0].view(-1,len(x[0][0])).unsqueeze(0)
predY = Prednet(x)
print(predY)
print(y[0][2])

# %%
def calcu_XY_point(predY,size):
    #input: [batchsize len features]; features:[velx,vely,x,y]
    '''
    deltaY = v0*delta_t + 0.5* a *delta_t^2
    a = (v - v0)/delta_t
    vo
    '''
    vels = predY[:,:,0:2]
    rst_xy = np.zeros(predY[:,:,0:2].shape)
    rst_xy[:,:-size,:] = predY[:,:-size,2:4]
    delta_t = 0.1
   
    for i in range(size):
        a = (vels[:,-(size-i),:] - vels[:,-(size+1-i),:])/delta_t
        delta_xy = vels[:,-(size-i),:]*vels[:,-(size-i),:]-vels[:,-(size+1-i),:]*vels[:,-(size+1-i),:]
        delta_xy = delta_xy/(2*a)
        rst_xy[:,-(size-i),:] = rst_xy[:,-(size+1-i),:] + delta_xy
    """
    for i in range(1,100):
        a = (vels[:,i,:] - vels[:,i-1,:])/delta_t
        delta_xy = vels[:,i,:]*vels[:,i-1,:]-vels[:,i-1,:]*vels[:,i-1,:]
        delta_xy = delta_xy/(2*a)
        rst_xy[:,i,:] = rst_xy[:,i-1,:] + delta_xy
       """
    return rst_xy

# %%
from behavior_model import LSTM
def compute_label(py):
    net_behavior = LSTM(1,5,256,2) 
    net_behavior.load_state_dict(torch.load('model/lstm_behavior_prediction_old.pt'))
    net_behavior.to(device)
    inputs = torch.from_numpy(py[:,-1,:-1].unsqueeze(2).detach().cpu().numpy().astype(np.float32)).to(device)
    h = net_behavior.init_hidden(py[:,-1,:-1].shape[0])
    h = tuple([each.data for each in h])
    behavior,h = net_behavior(inputs,h)
    _, class_ = torch.max(behavior, dim=1)
    class_ = class_.reshape(-1,1,1)
    class_ = torch.from_numpy(class_.detach().cpu().numpy().astype(np.double)).to(device)
    std = WholeSet.std.repeat(x.shape[0],1,1)
    std = std[:,:,-1].unsqueeze(1).to(device)
    mn = WholeSet.mn.repeat(x.shape[0],1,1)
    mn = mn[:,:,-1].unsqueeze(1).to(device)
    rg = WholeSet.range.repeat(x.shape[0],1,1)
    rg = rg[:,:,-1].unsqueeze(1).to(device)
    class_ = (class_ -mn) / (std*rg)
    py = torch.cat((py[:,-1,:-1].unsqueeze(1),class_),2)
    return py

# %%
x, y = test_iter.next()
x,y = x.to(device),y.to(device)
x = x[:,:50,:]
predY = x
py = predict_point(Prednet,predY)
print(compute_label(py).shape)
