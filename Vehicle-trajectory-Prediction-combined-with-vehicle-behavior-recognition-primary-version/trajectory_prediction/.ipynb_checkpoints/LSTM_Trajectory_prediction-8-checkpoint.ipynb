# %%
# -*- coding: utf-8 -*-

from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import time
import math
import random
import pandas as pd
import scipy.signal
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
import torch.distributions as dist
from trajectory_dataPrepare50 import *

torch.manual_seed(0)

MAX_LENGTH = 100
torch.cuda.set_device(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print('ok')
length = 100
predict_length=30
Training_generator, Test, Valid, WholeSet= get_dataloader(128,length,predict_length)

class NNPred(nn.Module):
    def __init__(self, input_size, output_size,hidden_size,batch_size, dropout=0.3):
        super(NNPred, self).__init__()
        
        self.batch_size = batch_size
        self.hidden_size = hidden_size
        self.num_layers = 2

        self.in2lstm = nn.Linear(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size,num_layers=self.num_layers,bidirectional=False,batch_first=True,dropout =dropout)
        self.in2bilstm = nn.Linear(input_size, hidden_size)
        self.bilstm = nn.LSTM(hidden_size, hidden_size//2,num_layers=self.num_layers,bidirectional=True,batch_first=True,dropout =dropout)
    
        self.fc0 = nn.Linear(hidden_size,hidden_size*2)
        self.fc1 = nn.Linear(hidden_size*2,int(hidden_size/2))
        self.in2out = nn.Linear(input_size, int(hidden_size/2))
        self.fc2 = nn.Linear(int(hidden_size/2) ,output_size)
        self.tanh = nn.Tanh()
        
    def forward(self, input):
        #input = tensor shape[batchsize, len, num_features]
        bilstm_out,_= self.bilstm(self.in2bilstm(input))
        lstm_out,_= self.lstm(self.in2lstm(input))
        out = self.tanh(self.fc0(lstm_out+bilstm_out))
        out = self.tanh(self.fc1(out))
        out =  out + self.in2out(input)
        output = self.fc2(out)# range [0 -> 1 ]
        return output
# Out:
# ok
# ****************************** ——-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-————-—— ******************************
# ---轨迹输入数据结构： torch.Size([128, 100, 68]) ---轨迹输出数据结构： torch.Size([128, 100, 4])
# ---轨迹长度： 100 ---预测轨迹长度： 30

# %%
import  torch
import numpy as np
f = [[[2,3],[4,5],[4,6]]]
d = [[[1,1,1]]]
print(np.array(f).shape,np.array(d).shape)
g = torch.tensor(d).bmm(torch.tensor(f))
print(g)
# Out:
# (1, 3, 2) (1, 1, 3)
# tensor([[[10, 14]]])

# %%
def trainIters(encoder, epoches,learning_rate=0.0001,print_every=7):
    start = time.time()
    # print_loss_total = 0  # Reset every print_every
 #  plot_loss_total = 0  # Reset every plot_every
    #criterion = nn.SmoothL1Loss()
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(encoder_optimizer,mode='min',factor=0.1,
patience=120,verbose=True,threshold=0.0001,threshold_mode='rel',cooldown=0,min_lr=0,eps=1e-015)
    #criterion = nn.MSELoss(reduction='sum')
    criterion = nn.MSELoss()
    loss_min = np.inf
    train_losses =[]
    valid_losses =[]
    encoder.train()
    for e in range(1, epoches + 1):
        train_loss = []
        for batch_i,(local_batch, local_labels) in enumerate(Training_generator):
            #if local_batch.shape[0]!=BatchSize:
             #   continue
            encoder.zero_grad()
            local_batch = local_batch.to(device)
            local_labels = local_labels.to(device)
            
            predY = encoder(local_batch)
            loss = criterion(predY,local_labels).to(device)
            loss.backward()
            encoder_optimizer.step()
            train_loss.append(loss.item())
            if batch_i % print_every == 0:     
                valid_loss = []
                encoder.eval()
                for x,y in Valid:
                    x,y = x.to(device),y.to(device)
                    predict = encoder(x)
                    loss_valid = criterion(predict,y)
                    valid_loss.append(loss_valid.item())
                encoder.train()
                train_loss_mean = np.mean(train_loss)
                valid_loss_mean = np.mean(valid_loss)
                train_losses.append(train_loss_mean)
                valid_losses.append(valid_loss_mean)
                scheduler.step(valid_loss_mean)
                print("Epoch:{}/{},Step:{}/{}".format(e,epoches,batch_i,len(Training_generator)),
                  "Train_Loss:{},Valid_Loss: {}".format(train_loss_mean,valid_loss_mean))
                if valid_loss_mean < loss_min :                             
                    print("valid_loss decrease!!!save the model.")
                    loss_min = valid_loss_mean
                    torch.save(encoder.state_dict(),'model/trajectory_predict_68_4_30.pt')
                #torch.save(encoder.state_dict(),'model/trajectory_predict_68_4_30_each.pt')
    plt.plot(train_losses,color = 'r',label = 'Train_Loss')
    plt.plot(valid_losses,color = 'g',label = 'Valid_Loss')
    plt.title('Loss_Trend')
    plt.xlabel('Epoches')
    plt.ylabel('Loss')
    #plt.title('损失变化')
    #plt.xlabel('迭代次数')
    #plt.ylabel('损失大小')
    plt.legend()
    plt.rcParams['font.sans-serif'] = ['SimHei']
    plt.savefig('image/trajectory_loss_improve_68_4_30.svg',dpi=600)
    plt.savefig('image/trajectory_loss_improve_68_4_30.png',dpi=600)

# %%
train_iter = iter(Training_generator)
x, y= train_iter.next()
print(x.shape,y.shape)
hidden_size = 256
Prednet = NNPred(x.shape[2], y.shape[2],hidden_size, x.shape[0])
# Out:
# torch.Size([128, 100, 68]) torch.Size([128, 100, 4])

# %%
# #print(device)

TRAN_TAG = True
if TRAN_TAG:
    if path.exists("model/trajectory_predict_68_4_30.pt"):
        Prednet.load_state_dict(torch.load('model/trajectory_predict_68_4_30.pt'))
    Prednet = Prednet.double()
    Prednet = Prednet.to(device)
    trainIters(Prednet, 1000,0.00001,20)
   # torch.save(Prednet.state_dict(), 'trajectory_predict.pt')
   # showPlot(plot_lo0sses)
else:
    Prednet.load_state_dict(torch.load('model/trajectory_predict_68_4_30.pt'))
    Prednet = Prednet.double()
    Prednet = Prednet.to(device)
    Prednet.eval()
    Eval_net(Prednet)
# Out:
# Epoch:1/1000,Step:0/109 Train_Loss:0.0002042465339541969,Valid_Loss: 0.002357914998149412
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:20/109 Train_Loss:0.00019553506174377496,Valid_Loss: 0.0023326568426352634
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:40/109 Train_Loss:0.00018985094635720607,Valid_Loss: 0.0023305492943781923
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:60/109 Train_Loss:0.00038703364289354277,Valid_Loss: 0.002318745112441689
# valid_loss decrease!!!save the model.
# Epoch:1/1000,Step:80/109 Train_Loss:0.00033653805319302686,Valid_Loss: 0.0023189519608833244
# Epoch:1/1000,Step:100/109 Train_Loss:0.0003047977274777402,Valid_Loss: 0.002317989824720908
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:0/109 Train_Loss:0.00017258468284009096,Valid_Loss: 0.0023226818525666207
# Epoch:2/1000,Step:20/109 Train_Loss:0.00017745869279526486,Valid_Loss: 0.0023253120242951717
# Epoch:2/1000,Step:40/109 Train_Loss:0.00017795190749009805,Valid_Loss: 0.002326494011564551
# Epoch:2/1000,Step:60/109 Train_Loss:0.0003784639937493809,Valid_Loss: 0.0023201456515212658
# Epoch:2/1000,Step:80/109 Train_Loss:0.00032936019872932516,Valid_Loss: 0.0023158828283770436
# valid_loss decrease!!!save the model.
# Epoch:2/1000,Step:100/109 Train_Loss:0.0002992127482940801,Valid_Loss: 0.002316712722867255
# Epoch:3/1000,Step:0/109 Train_Loss:0.00015517018139397663,Valid_Loss: 0.0023184689332172827
# Epoch:3/1000,Step:20/109 Train_Loss:0.000754176121036824,Valid_Loss: 0.002313612282831986
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:40/109 Train_Loss:0.0004729298932041293,Valid_Loss: 0.00231252368454767
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:60/109 Train_Loss:0.00037628411577998375,Valid_Loss: 0.0023123673691520167
# valid_loss decrease!!!save the model.
# Epoch:3/1000,Step:80/109 Train_Loss:0.00032663449603633117,Valid_Loss: 0.0023156118451354247
# Epoch:3/1000,Step:100/109 Train_Loss:0.0002970136316335758,Valid_Loss: 0.002315149090282351
# Epoch:4/1000,Step:0/109 Train_Loss:0.0002030975258801355,Valid_Loss: 0.00232188936813323
# Epoch:4/1000,Step:20/109 Train_Loss:0.0007606530402695544,Valid_Loss: 0.0023140724572935653
# Epoch:4/1000,Step:40/109 Train_Loss:0.0004760429558157285,Valid_Loss: 0.00231086753236476
# valid_loss decrease!!!save the model.
# Epoch:4/1000,Step:60/109 Train_Loss:0.0003780643205566143,Valid_Loss: 0.004084290194420776
# Epoch:4/1000,Step:80/109 Train_Loss:0.00032762837485872273,Valid_Loss: 0.002315182857183772
# Epoch:4/1000,Step:100/109 Train_Loss:0.0002983438655313247,Valid_Loss: 0.0023145540281881184
# Epoch:5/1000,Step:0/109 Train_Loss:0.00017648379995199075,Valid_Loss: 0.00409408117732692
# Epoch:5/1000,Step:20/109 Train_Loss:0.00017829549930678095,Valid_Loss: 0.0023133780567817165
# Epoch:5/1000,Step:40/109 Train_Loss:0.00047239393464330566,Valid_Loss: 0.004083408419383004
# Epoch:5/1000,Step:60/109 Train_Loss:0.00037597920839686956,Valid_Loss: 0.0023096918691165804
# valid_loss decrease!!!save the model.
# Epoch:5/1000,Step:80/109 Train_Loss:0.00032631986378757157,Valid_Loss: 0.002310709254252808
# Epoch:5/1000,Step:100/109 Train_Loss:0.00029646276618555006,Valid_Loss: 0.0023116665523355137
# Epoch:6/1000,Step:0/109 Train_Loss:0.00017291197302189037,Valid_Loss: 0.0040982248337970715
# Epoch:6/1000,Step:20/109 Train_Loss:0.00017498399666091645,Valid_Loss: 0.002311467556233952
# Epoch:6/1000,Step:40/109 Train_Loss:0.00017480689283646042,Valid_Loss: 0.002315757339756314
# Epoch:6/1000,Step:60/109 Train_Loss:0.00017481185758086426,Valid_Loss: 0.0023214373530174677
# Epoch:6/1000,Step:80/109 Train_Loss:0.00032548418083896367,Valid_Loss: 0.00230751860655662
# valid_loss decrease!!!save the model.
# Epoch:6/1000,Step:100/109 Train_Loss:0.0002961059619377643,Valid_Loss: 0.0023088078321635806
# Epoch:7/1000,Step:0/109 Train_Loss:0.000160107043889961,Valid_Loss: 0.002309235882769483
# Epoch:7/1000,Step:20/109 Train_Loss:0.0007568220384477403,Valid_Loss: 0.0023006348530933427
# valid_loss decrease!!!save the model.
# Epoch:7/1000,Step:40/109 Train_Loss:0.00047425991387872117,Valid_Loss: 0.0023043487065586197
# Epoch:7/1000,Step:60/109 Train_Loss:0.0003753764614475548,Valid_Loss: 0.002314017167010496
# Epoch:7/1000,Step:80/109 Train_Loss:0.0003266066687710285,Valid_Loss: 0.0023048009035350455
# Epoch:7/1000,Step:100/109 Train_Loss:0.0002963351603690514,Valid_Loss: 0.0023065185974161283
# Epoch:8/1000,Step:0/109 Train_Loss:0.00016802274610608461,Valid_Loss: 0.002311809125715604
# Epoch:8/1000,Step:20/109 Train_Loss:0.000174075059398745,Valid_Loss: 0.00408116811903266
# Epoch:8/1000,Step:40/109 Train_Loss:0.00017313363036522292,Valid_Loss: 0.002311440976930563
# Epoch:8/1000,Step:60/109 Train_Loss:0.00037273810070754176,Valid_Loss: 0.00230445784714728
# Epoch:8/1000,Step:80/109 Train_Loss:0.0003244221974317567,Valid_Loss: 0.0023076906500449175
# Epoch:8/1000,Step:100/109 Train_Loss:0.0002952240244442871,Valid_Loss: 0.002303380570313787
# Epoch:9/1000,Step:0/109 Train_Loss:0.00017306428650688807,Valid_Loss: 0.0023052434145441323
# Epoch:9/1000,Step:20/109 Train_Loss:0.00017501321358213452,Valid_Loss: 0.0023079069684820335
# Epoch:9/1000,Step:40/109 Train_Loss:0.00017512930146523076,Valid_Loss: 0.0023128300553713183
# Epoch:9/1000,Step:60/109 Train_Loss:0.00017486894245606803,Valid_Loss: 0.0023111600935046754
# Epoch:9/1000,Step:80/109 Train_Loss:0.00032566161822138146,Valid_Loss: 0.0023084352873350934
# Epoch:9/1000,Step:100/109 Train_Loss:0.0002960149469903495,Valid_Loss: 0.0023052235140887584
# Epoch:10/1000,Step:0/109 Train_Loss:0.0001808059779677661,Valid_Loss: 0.0023032258756128343
# Epoch:10/1000,Step:20/109 Train_Loss:0.00017237349460709012,Valid_Loss: 0.002314409730506455
# Epoch:10/1000,Step:40/109 Train_Loss:0.0001750857794999487,Valid_Loss: 0.002307445365446265
# Epoch:10/1000,Step:60/109 Train_Loss:0.00017483844362157632,Valid_Loss: 0.002308189838528415
# Epoch:10/1000,Step:80/109 Train_Loss:0.000324974703518451,Valid_Loss: 0.0022994822197769937
# valid_loss decrease!!!save the model.
# Epoch:10/1000,Step:100/109 Train_Loss:0.000295297772805044,Valid_Loss: 0.0023039139116536158
# Epoch:11/1000,Step:0/109 Train_Loss:0.00016218430984744572,Valid_Loss: 0.0023023886202564216
# Epoch:11/1000,Step:20/109 Train_Loss:0.0007570758731328742,Valid_Loss: 0.0022935847827203733
# valid_loss decrease!!!save the model.
# Epoch:11/1000,Step:40/109 Train_Loss:0.00047238629335525875,Valid_Loss: 0.0022976868976867905
# Epoch:11/1000,Step:60/109 Train_Loss:0.00037485852765213357,Valid_Loss: 0.002294932301710633
# Epoch:11/1000,Step:80/109 Train_Loss:0.0003252732695345536,Valid_Loss: 0.0022963915675454165
# Epoch:11/1000,Step:100/109 Train_Loss:0.00029529452488788243,Valid_Loss: 0.0023008054065370327
# Epoch:12/1000,Step:0/109 Train_Loss:0.00018028777639967586,Valid_Loss: 0.0023013376247790138
# Epoch:12/1000,Step:20/109 Train_Loss:0.00017242516194942168,Valid_Loss: 0.0023037799299058426
# Epoch:12/1000,Step:40/109 Train_Loss:0.0001736079817499656,Valid_Loss: 0.0023025250686149025
# Epoch:12/1000,Step:60/109 Train_Loss:0.00017364822658871,Valid_Loss: 0.002304084370423587
# Epoch:12/1000,Step:80/109 Train_Loss:0.00017403440220800705,Valid_Loss: 0.0023045936572680995
# Epoch:12/1000,Step:100/109 Train_Loss:0.00029483638039995896,Valid_Loss: 0.002301322535355896
# Epoch:13/1000,Step:0/109 Train_Loss:0.0001783024613710777,Valid_Loss: 0.002299979320782849
# Epoch:13/1000,Step:20/109 Train_Loss:0.000178562788486219,Valid_Loss: 0.0022983014231812314
# Epoch:13/1000,Step:40/109 Train_Loss:0.00017645761580105127,Valid_Loss: 0.0022989359918906887
# Epoch:13/1000,Step:60/109 Train_Loss:0.000175528153825278,Valid_Loss: 0.0023007011738897937
# Epoch:13/1000,Step:80/109 Train_Loss:0.00017509509764063983,Valid_Loss: 0.002305326460949168
# Epoch:13/1000,Step:100/109 Train_Loss:0.00017476048672128948,Valid_Loss: 0.004070529938429897
# Epoch:14/1000,Step:0/109 Train_Loss:0.00018508831216772743,Valid_Loss: 0.002297267968256607
# Epoch:14/1000,Step:20/109 Train_Loss:0.00017462874373827547,Valid_Loss: 0.0040560711706393955
# Epoch:14/1000,Step:40/109 Train_Loss:0.0001745237677612038,Valid_Loss: 0.002298852696559086
# Epoch:14/1000,Step:60/109 Train_Loss:0.0001752134080915281,Valid_Loss: 0.002301728927757825
# Epoch:14/1000,Step:80/109 Train_Loss:0.0001748058071396537,Valid_Loss: 0.002301082735731479
# Epoch:14/1000,Step:100/109 Train_Loss:0.00029448492837916637,Valid_Loss: 0.0022902471344553076
# valid_loss decrease!!!save the model.
# Epoch:15/1000,Step:0/109 Train_Loss:0.0001797659152050559,Valid_Loss: 0.002297115746787175
# Epoch:15/1000,Step:20/109 Train_Loss:0.00017758380800170768,Valid_Loss: 0.002311329671195485
# Epoch:15/1000,Step:40/109 Train_Loss:0.000176276437369825,Valid_Loss: 0.004058550542285873
# Epoch:15/1000,Step:60/109 Train_Loss:0.00017469590137118163,Valid_Loss: 0.0023041864154938986
# Epoch:15/1000,Step:80/109 Train_Loss:0.0001753173640788762,Valid_Loss: 0.0022993971037845637
# Epoch:15/1000,Step:100/109 Train_Loss:0.00029429105087204455,Valid_Loss: 0.0022954017973914388
# Epoch:16/1000,Step:0/109 Train_Loss:0.0001692925449984859,Valid_Loss: 0.0022938483746094683
# Epoch:16/1000,Step:20/109 Train_Loss:0.00017525890546344277,Valid_Loss: 0.002293924309376645
# Epoch:16/1000,Step:40/109 Train_Loss:0.00046757050089655253,Valid_Loss: 0.0022900547786414253
# valid_loss decrease!!!save the model.
# Epoch:16/1000,Step:60/109 Train_Loss:0.00037153729343628554,Valid_Loss: 0.002287079646532267
# valid_loss decrease!!!save the model.
# Epoch:16/1000,Step:80/109 Train_Loss:0.00032307050741354316,Valid_Loss: 0.0022858539019605163
# valid_loss decrease!!!save the model.
# Epoch:16/1000,Step:100/109 Train_Loss:0.0002935222233728029,Valid_Loss: 0.0022885931692066324
# Epoch:17/1000,Step:0/109 Train_Loss:0.00020409091035990877,Valid_Loss: 0.0022895919562698212
# Epoch:17/1000,Step:20/109 Train_Loss:0.0007493763732083211,Valid_Loss: 0.0022866278929344072
# Epoch:17/1000,Step:40/109 Train_Loss:0.00046862067001118715,Valid_Loss: 0.002289785250158154
# Epoch:17/1000,Step:60/109 Train_Loss:0.0003738829185840359,Valid_Loss: 0.0022877280029778477
# Epoch:17/1000,Step:80/109 Train_Loss:0.0003253162775461523,Valid_Loss: 0.002288110947727773
# Epoch:17/1000,Step:100/109 Train_Loss:0.00029445823900141663,Valid_Loss: 0.002287197118159878
# Epoch:18/1000,Step:0/109 Train_Loss:0.00018241802186694464,Valid_Loss: 0.00228587491327475
# Epoch:18/1000,Step:20/109 Train_Loss:0.0001762321813858115,Valid_Loss: 0.002304921408156736
# Epoch:18/1000,Step:40/109 Train_Loss:0.00017586757631206138,Valid_Loss: 0.002290071016320768
# Epoch:18/1000,Step:60/109 Train_Loss:0.00017510521527664457,Valid_Loss: 0.0022902786786367134
# Epoch:18/1000,Step:80/109 Train_Loss:0.0001747301885686291,Valid_Loss: 0.002292213506643687
# Epoch:18/1000,Step:100/109 Train_Loss:0.00017482189850787162,Valid_Loss: 0.0022973741584616583
# Epoch:19/1000,Step:0/109 Train_Loss:0.00017439741886542354,Valid_Loss: 0.002298727323539304
# Epoch:19/1000,Step:20/109 Train_Loss:0.00017238675043931536,Valid_Loss: 0.0022864412251335786
# Epoch:19/1000,Step:40/109 Train_Loss:0.00017274278270825214,Valid_Loss: 0.002286609931150519
# Epoch:19/1000,Step:60/109 Train_Loss:0.0001727865768867406,Valid_Loss: 0.002291779923989053
# Epoch:19/1000,Step:80/109 Train_Loss:0.00017303919343301152,Valid_Loss: 0.002290683559233849
# Epoch:19/1000,Step:100/109 Train_Loss:0.00017360525485564024,Valid_Loss: 0.002292299717398254
# Epoch:20/1000,Step:0/109 Train_Loss:0.00017349442357346661,Valid_Loss: 0.002288533044040263
# Epoch:20/1000,Step:20/109 Train_Loss:0.0001804373095897776,Valid_Loss: 0.002267457145959496
# valid_loss decrease!!!save the model.
# Epoch:20/1000,Step:40/109 Train_Loss:0.0004680691035202677,Valid_Loss: 0.00226122966186184
# valid_loss decrease!!!save the model.
# Epoch:20/1000,Step:60/109 Train_Loss:0.0003721281404922372,Valid_Loss: 0.002265938564048202
# Epoch:20/1000,Step:80/109 Train_Loss:0.00032329956281592964,Valid_Loss: 0.0022644337445157136
# Epoch:20/1000,Step:100/109 Train_Loss:0.00029383240525536323,Valid_Loss: 0.0022782861091353124
# Epoch:21/1000,Step:0/109 Train_Loss:0.0001692463362141969,Valid_Loss: 0.002271313550804771
# Epoch:21/1000,Step:20/109 Train_Loss:0.00017724875059945804,Valid_Loss: 0.0022712297446599887
# Epoch:21/1000,Step:40/109 Train_Loss:0.0001743361701346279,Valid_Loss: 0.0022727161155923245
# Epoch:21/1000,Step:60/109 Train_Loss:0.00017309361280863454,Valid_Loss: 0.0022725544759207425
# Epoch:21/1000,Step:80/109 Train_Loss:0.0001726420188505114,Valid_Loss: 0.002275372375652658
# Epoch:21/1000,Step:100/109 Train_Loss:0.00029195722872191285,Valid_Loss: 0.002267272613507141
# Epoch:22/1000,Step:0/109 Train_Loss:0.00016366072283810845,Valid_Loss: 0.002273992041068933
# Epoch:22/1000,Step:20/109 Train_Loss:0.0001734850335429884,Valid_Loss: 0.0022682338784597543
# Epoch:22/1000,Step:40/109 Train_Loss:0.00017479574430356786,Valid_Loss: 0.0022720534829404663
# Epoch:22/1000,Step:60/109 Train_Loss:0.00017342246459154157,Valid_Loss: 0.0022728695594216824
# Epoch:22/1000,Step:80/109 Train_Loss:0.0003211986484311288,Valid_Loss: 0.002271645116363384
# Epoch:22/1000,Step:100/109 Train_Loss:0.00029223553423954194,Valid_Loss: 0.002264230807781482
# Epoch:23/1000,Step:0/109 Train_Loss:0.00015858822111599168,Valid_Loss: 0.0022676146449398943
# Epoch:23/1000,Step:20/109 Train_Loss:0.00017221546186834286,Valid_Loss: 0.0022730678196221507
# Epoch:23/1000,Step:40/109 Train_Loss:0.00017239718961127966,Valid_Loss: 0.0022724540260805064
# Epoch:23/1000,Step:60/109 Train_Loss:0.0001721796695891352,Valid_Loss: 0.002271009733676841
# Epoch:23/1000,Step:80/109 Train_Loss:0.00031993017121960437,Valid_Loss: 0.0022702641950897275
# Epoch:23/1000,Step:100/109 Train_Loss:0.0002911242304678537,Valid_Loss: 0.0022662355757007385
# Epoch:24/1000,Step:0/109 Train_Loss:0.00015433294787104812,Valid_Loss: 0.004002537492354649
# Epoch:24/1000,Step:20/109 Train_Loss:0.0001713450795459444,Valid_Loss: 0.0022674616793805433
# Epoch:24/1000,Step:40/109 Train_Loss:0.0001724393680172634,Valid_Loss: 0.0022694775725507865
# Epoch:24/1000,Step:60/109 Train_Loss:0.00036847001361243066,Valid_Loss: 0.002266350410726326
# Epoch:24/1000,Step:80/109 Train_Loss:0.00031985767137047565,Valid_Loss: 0.0022642028625272067
# Epoch:24/1000,Step:100/109 Train_Loss:0.00029170508925877405,Valid_Loss: 0.003998931594861499
# Epoch:25/1000,Step:0/109 Train_Loss:0.00017018739916340725,Valid_Loss: 0.0022649774819994513
# Epoch:25/1000,Step:20/109 Train_Loss:0.00017783634032691233,Valid_Loss: 0.002267697620227205
# Epoch:25/1000,Step:40/109 Train_Loss:0.00017562964634149173,Valid_Loss: 0.0022695224249573783
# Epoch:25/1000,Step:60/109 Train_Loss:0.00037116632962961953,Valid_Loss: 0.0022606590595350166
# valid_loss decrease!!!save the model.
# Epoch:25/1000,Step:80/109 Train_Loss:0.00032188167725590537,Valid_Loss: 0.00227497264167633
# Epoch:25/1000,Step:100/109 Train_Loss:0.00029249506623117304,Valid_Loss: 0.0022634441576519547
# Epoch:26/1000,Step:0/109 Train_Loss:0.00018176196648005206,Valid_Loss: 0.00226722105890833
# Epoch:26/1000,Step:20/109 Train_Loss:0.00017238344420994115,Valid_Loss: 0.0022739538131158433
# Epoch:26/1000,Step:40/109 Train_Loss:0.00046493858545018564,Valid_Loss: 0.0022674673332256654
# Epoch:26/1000,Step:60/109 Train_Loss:0.00037058406715912887,Valid_Loss: 0.0022613198732382017
# Epoch:26/1000,Step:80/109 Train_Loss:0.0003221232410856881,Valid_Loss: 0.0022631026944409543
# Epoch:26/1000,Step:100/109 Train_Loss:0.000292885856710327,Valid_Loss: 0.0022655505575908475
# Epoch:27/1000,Step:0/109 Train_Loss:0.00020074983446695762,Valid_Loss: 0.0022668276076346847
# Epoch:27/1000,Step:20/109 Train_Loss:0.000739004966251563,Valid_Loss: 0.0022535730303507033
# valid_loss decrease!!!save the model.
# Epoch:27/1000,Step:40/109 Train_Loss:0.00046306764087982095,Valid_Loss: 0.0022576209198790992
# Epoch:27/1000,Step:60/109 Train_Loss:0.0003680050132107818,Valid_Loss: 0.002260848455358367
# Epoch:27/1000,Step:80/109 Train_Loss:0.00031956031337849295,Valid_Loss: 0.002263763958643332
# Epoch:27/1000,Step:100/109 Train_Loss:0.00029083634570870064,Valid_Loss: 0.0022637436262040707
# Epoch:28/1000,Step:0/109 Train_Loss:0.0001710309487506737,Valid_Loss: 0.002270730216921704
# Epoch:28/1000,Step:20/109 Train_Loss:0.00017534460375681561,Valid_Loss: 0.004012725767850079
# Epoch:28/1000,Step:40/109 Train_Loss:0.000173781332896205,Valid_Loss: 0.0022695987660297954
# Epoch:28/1000,Step:60/109 Train_Loss:0.00017319549445095594,Valid_Loss: 0.0022693451465968946
# Epoch:28/1000,Step:80/109 Train_Loss:0.0003212093307244508,Valid_Loss: 0.002261996228735718
# Epoch:28/1000,Step:100/109 Train_Loss:0.00029202706054737906,Valid_Loss: 0.0022608620374126344
# Epoch:29/1000,Step:0/109 Train_Loss:0.00017683784364829535,Valid_Loss: 0.002261906506224796
# Epoch:29/1000,Step:20/109 Train_Loss:0.0001719009115143958,Valid_Loss: 0.003994783447406186
# Epoch:29/1000,Step:40/109 Train_Loss:0.00017265419312202296,Valid_Loss: 0.0022611077724974953
# Epoch:29/1000,Step:60/109 Train_Loss:0.0001724114291088208,Valid_Loss: 0.002268872065597009
# Epoch:29/1000,Step:80/109 Train_Loss:0.00017201292269954598,Valid_Loss: 0.0022656672606570227
# Epoch:29/1000,Step:100/109 Train_Loss:0.00029078074480672083,Valid_Loss: 0.0022610710257414636
# Epoch:30/1000,Step:0/109 Train_Loss:0.00017638636274199822,Valid_Loss: 0.002260444409149073
# Epoch:30/1000,Step:20/109 Train_Loss:0.00017557769919090646,Valid_Loss: 0.0022594804483401267
# Epoch:30/1000,Step:40/109 Train_Loss:0.0004642584652346218,Valid_Loss: 0.0022556501594069057
# Epoch:30/1000,Step:60/109 Train_Loss:0.0003678295091413394,Valid_Loss: 0.0022496193921412153
# valid_loss decrease!!!save the model.
# Epoch:30/1000,Step:80/109 Train_Loss:0.00032027694288593413,Valid_Loss: 0.002254727810878722
# Epoch:30/1000,Step:100/109 Train_Loss:0.0002909692730781233,Valid_Loss: 0.0022564284936948697
# Epoch:31/1000,Step:0/109 Train_Loss:0.00015381529823931575,Valid_Loss: 0.002258280791784158
# Epoch:31/1000,Step:20/109 Train_Loss:0.0001717312022530449,Valid_Loss: 0.0039905738987632885
# Epoch:31/1000,Step:40/109 Train_Loss:0.0004641125864260532,Valid_Loss: 0.0022537316176879157
# Epoch:31/1000,Step:60/109 Train_Loss:0.00036864105702122407,Valid_Loss: 0.002250304715689711
# Epoch:31/1000,Step:80/109 Train_Loss:0.0003198505757556196,Valid_Loss: 0.002253679680515458
# Epoch:31/1000,Step:100/109 Train_Loss:0.0002909280506924147,Valid_Loss: 0.002253220816774231
# Epoch:32/1000,Step:0/109 Train_Loss:0.00016697064602281365,Valid_Loss: 0.0022560246152078657
# Epoch:32/1000,Step:20/109 Train_Loss:0.00017376202863440468,Valid_Loss: 0.0022573852692658264
# Epoch:32/1000,Step:40/109 Train_Loss:0.0001732715329848312,Valid_Loss: 0.0022565208822420517
# Epoch:32/1000,Step:60/109 Train_Loss:0.00017324344756575798,Valid_Loss: 0.002260950154481556
# Epoch:32/1000,Step:80/109 Train_Loss:0.00017298241720772834,Valid_Loss: 0.0022630082484985
# Epoch:32/1000,Step:100/109 Train_Loss:0.00029092693083883597,Valid_Loss: 0.0022602289551879704
# Epoch:33/1000,Step:0/109 Train_Loss:0.0001811533221166455,Valid_Loss: 0.0022580955581791794
# Epoch:33/1000,Step:20/109 Train_Loss:0.0007350244317097784,Valid_Loss: 0.0022622240646173754
# Epoch:33/1000,Step:40/109 Train_Loss:0.000462718232025702,Valid_Loss: 0.002247720828623464
# valid_loss decrease!!!save the model.
# Epoch:33/1000,Step:60/109 Train_Loss:0.0003684682268469279,Valid_Loss: 0.002249700104337917
# Epoch:33/1000,Step:80/109 Train_Loss:0.00032027911189787375,Valid_Loss: 0.002251943407262123
# Epoch:33/1000,Step:100/109 Train_Loss:0.00029102220764087253,Valid_Loss: 0.00225057982566972
# Epoch:34/1000,Step:0/109 Train_Loss:0.0001566414082172923,Valid_Loss: 0.0022572657968992745
# Epoch:34/1000,Step:20/109 Train_Loss:0.00017634135008464787,Valid_Loss: 0.0022564755370505334
# Epoch:34/1000,Step:40/109 Train_Loss:0.00017487095498942696,Valid_Loss: 0.0022611501272426543
# Epoch:34/1000,Step:60/109 Train_Loss:0.00017370698274167315,Valid_Loss: 0.002262447454988128
# Epoch:34/1000,Step:80/109 Train_Loss:0.000319831830759933,Valid_Loss: 0.0022523618761522584
# Epoch:34/1000,Step:100/109 Train_Loss:0.00029056397980921567,Valid_Loss: 0.002254126008927271
# Epoch:35/1000,Step:0/109 Train_Loss:0.00017557773995986628,Valid_Loss: 0.0022562164413313652
# Epoch:35/1000,Step:20/109 Train_Loss:0.0007411846455744269,Valid_Loss: 0.0022532622255716033
# Epoch:35/1000,Step:40/109 Train_Loss:0.0004652816357683811,Valid_Loss: 0.0022460290345905866
# valid_loss decrease!!!save the model.
# Epoch:35/1000,Step:60/109 Train_Loss:0.00036956432230533196,Valid_Loss: 0.0022487919724658717
# Epoch:35/1000,Step:80/109 Train_Loss:0.00032045400856400765,Valid_Loss: 0.0022518553190653406
# Epoch:35/1000,Step:100/109 Train_Loss:0.00029122023100399726,Valid_Loss: 0.0022504581876114484
# Epoch:36/1000,Step:0/109 Train_Loss:0.00017258437500795407,Valid_Loss: 0.0022512704602427225
# Epoch:36/1000,Step:20/109 Train_Loss:0.00017105986559037552,Valid_Loss: 0.0022509108528472855
# Epoch:36/1000,Step:40/109 Train_Loss:0.00017498372042867172,Valid_Loss: 0.0022596109448284806
# Epoch:36/1000,Step:60/109 Train_Loss:0.00017330930393097082,Valid_Loss: 0.002255910047935041
# Epoch:36/1000,Step:80/109 Train_Loss:0.00017258366645813924,Valid_Loss: 0.002256162755379962
# Epoch:36/1000,Step:100/109 Train_Loss:0.00029053815888069676,Valid_Loss: 0.0022503573205848036
# Epoch:37/1000,Step:0/109 Train_Loss:0.00016720223466099477,Valid_Loss: 0.0022461669561073087
# Epoch:37/1000,Step:20/109 Train_Loss:0.00017147161703778523,Valid_Loss: 0.0022454609480272963
# valid_loss decrease!!!save the model.
# Epoch:37/1000,Step:40/109 Train_Loss:0.0004587619828163075,Valid_Loss: 0.002245325140166541
# valid_loss decrease!!!save the model.
# Epoch:37/1000,Step:60/109 Train_Loss:0.00036666282733701543,Valid_Loss: 0.002251620830142699
# Epoch:37/1000,Step:80/109 Train_Loss:0.00031821453263175775,Valid_Loss: 0.002242935821324039
# valid_loss decrease!!!save the model.
# Epoch:37/1000,Step:100/109 Train_Loss:0.00029005575199003415,Valid_Loss: 0.0022441721862106402
# Epoch:38/1000,Step:0/109 Train_Loss:0.00016517341945761693,Valid_Loss: 0.0022450819277633504
# Epoch:38/1000,Step:20/109 Train_Loss:0.00017176832619970333,Valid_Loss: 0.002245800220626981
# Epoch:38/1000,Step:40/109 Train_Loss:0.00017138436055422117,Valid_Loss: 0.0022502201266089055
# Epoch:38/1000,Step:60/109 Train_Loss:0.00017245765617747083,Valid_Loss: 0.002250184226793718
# Epoch:38/1000,Step:80/109 Train_Loss:0.0001718697997891565,Valid_Loss: 0.002254067884882089
# Epoch:38/1000,Step:100/109 Train_Loss:0.00028970818357902553,Valid_Loss: 0.0022410713295817307
# valid_loss decrease!!!save the model.
# Epoch:39/1000,Step:0/109 Train_Loss:0.00016584423995964594,Valid_Loss: 0.0022444964614771862
# Epoch:39/1000,Step:20/109 Train_Loss:0.00016879586816851563,Valid_Loss: 0.0022471773276535947
# Epoch:39/1000,Step:40/109 Train_Loss:0.00017101655553382222,Valid_Loss: 0.0022471461186830783
# Epoch:39/1000,Step:60/109 Train_Loss:0.00017088830297076136,Valid_Loss: 0.002247465498930394
# Epoch:39/1000,Step:80/109 Train_Loss:0.0003168541882956057,Valid_Loss: 0.002240889894981869
# valid_loss decrease!!!save the model.
# Epoch:39/1000,Step:100/109 Train_Loss:0.0002884389644410756,Valid_Loss: 0.00224303189376453
# Epoch:40/1000,Step:0/109 Train_Loss:0.00016969867074189795,Valid_Loss: 0.002242611247621577
# Epoch:40/1000,Step:20/109 Train_Loss:0.00017442070980903357,Valid_Loss: 0.002241548577350735
# Epoch:40/1000,Step:40/109 Train_Loss:0.00017395463840841566,Valid_Loss: 0.0022438402851277504
# Epoch:40/1000,Step:60/109 Train_Loss:0.0003669737294585593,Valid_Loss: 0.002236139545494477
# valid_loss decrease!!!save the model.
# Epoch:40/1000,Step:80/109 Train_Loss:0.00031851327923797094,Valid_Loss: 0.002253695127690187
# Epoch:40/1000,Step:100/109 Train_Loss:0.0002886606583316133,Valid_Loss: 0.0022415717086972068
# Epoch:41/1000,Step:0/109 Train_Loss:0.00017839009510694666,Valid_Loss: 0.0022455019766831168
# Epoch:41/1000,Step:20/109 Train_Loss:0.0001731163157282656,Valid_Loss: 0.0022458907119738596
# Epoch:41/1000,Step:40/109 Train_Loss:0.00045988311701091806,Valid_Loss: 0.0022347054849648808
# valid_loss decrease!!!save the model.
# Epoch:41/1000,Step:60/109 Train_Loss:0.00036648846191909406,Valid_Loss: 0.002236677812515793
# Epoch:41/1000,Step:80/109 Train_Loss:0.0003190575630546645,Valid_Loss: 0.002238665997123856
# Epoch:41/1000,Step:100/109 Train_Loss:0.00029048804130297676,Valid_Loss: 0.002246684341599356
# Epoch:42/1000,Step:0/109 Train_Loss:0.00017795516316498956,Valid_Loss: 0.0022442742213535437
# Epoch:42/1000,Step:20/109 Train_Loss:0.00017148711699961814,Valid_Loss: 0.0022452237864056834
# Epoch:42/1000,Step:40/109 Train_Loss:0.00017288965775191258,Valid_Loss: 0.0022466300413279106
# Epoch:42/1000,Step:60/109 Train_Loss:0.00017192917900878121,Valid_Loss: 0.002248518942892327
# Epoch:42/1000,Step:80/109 Train_Loss:0.0001722333955464321,Valid_Loss: 0.0022475660130392696
# Epoch:42/1000,Step:100/109 Train_Loss:0.0002887239558751983,Valid_Loss: 0.002243997925673243
# Epoch:43/1000,Step:0/109 Train_Loss:0.00015960524016335326,Valid_Loss: 0.0022404861144532185
# Epoch:43/1000,Step:20/109 Train_Loss:0.00017131567770267415,Valid_Loss: 0.0022408279745599635
# Epoch:43/1000,Step:40/109 Train_Loss:0.0004587583673391062,Valid_Loss: 0.0022342307740418374
# valid_loss decrease!!!save the model.
# Epoch:43/1000,Step:60/109 Train_Loss:0.00036484537446720863,Valid_Loss: 0.002235019781245282
# Epoch:43/1000,Step:80/109 Train_Loss:0.0003181216634776268,Valid_Loss: 0.0022345602985314656
# Epoch:43/1000,Step:100/109 Train_Loss:0.0002884335920233635,Valid_Loss: 0.0022480728697007214
# Epoch:44/1000,Step:0/109 Train_Loss:0.00017666560281843441,Valid_Loss: 0.002238203744964243
# Epoch:44/1000,Step:20/109 Train_Loss:0.0001716369333116811,Valid_Loss: 0.0022381878942231907
# Epoch:44/1000,Step:40/109 Train_Loss:0.00045927942218162613,Valid_Loss: 0.0022424997966523736
# Epoch:44/1000,Step:60/109 Train_Loss:0.00036482546072752015,Valid_Loss: 0.002233352424250469
# valid_loss decrease!!!save the model.
# Epoch:44/1000,Step:80/109 Train_Loss:0.0003173961692792117,Valid_Loss: 0.002233535014222958
# Epoch:44/1000,Step:100/109 Train_Loss:0.0002891276189047414,Valid_Loss: 0.003948443541893638
# Epoch:45/1000,Step:0/109 Train_Loss:0.0002075851574653893,Valid_Loss: 0.002240274391614605
# Epoch:45/1000,Step:20/109 Train_Loss:0.00017227224345932877,Valid_Loss: 0.0022412598715194766
# Epoch:45/1000,Step:40/109 Train_Loss:0.00017309988724082523,Valid_Loss: 0.002237942945448786
# Epoch:45/1000,Step:60/109 Train_Loss:0.0001724989253390485,Valid_Loss: 0.0022367508970266847
# Epoch:45/1000,Step:80/109 Train_Loss:0.00031682980948630505,Valid_Loss: 0.002230559974252617
# valid_loss decrease!!!save the model.
# Epoch:45/1000,Step:100/109 Train_Loss:0.00028921255468810617,Valid_Loss: 0.002232194532912286
# Epoch:46/1000,Step:0/109 Train_Loss:0.00015936282225744103,Valid_Loss: 0.0022360195882677697
# Epoch:46/1000,Step:20/109 Train_Loss:0.00016900239273376247,Valid_Loss: 0.002235569142634479
# Epoch:46/1000,Step:40/109 Train_Loss:0.0004560867065717076,Valid_Loss: 0.002227356623379226
# valid_loss decrease!!!save the model.
# Epoch:46/1000,Step:60/109 Train_Loss:0.0003637805194929103,Valid_Loss: 0.002235033818073649
# Epoch:46/1000,Step:80/109 Train_Loss:0.0003176054291107772,Valid_Loss: 0.0022312069182804915
# Epoch:46/1000,Step:100/109 Train_Loss:0.00028929942919743033,Valid_Loss: 0.002233865125359407
# Epoch:47/1000,Step:0/109 Train_Loss:0.00018233104603698535,Valid_Loss: 0.0022335898183647243
# Epoch:47/1000,Step:20/109 Train_Loss:0.0001740519694704111,Valid_Loss: 0.0022361553870619212
# Epoch:47/1000,Step:40/109 Train_Loss:0.00017232168339004862,Valid_Loss: 0.002234057836426103
# Epoch:47/1000,Step:60/109 Train_Loss:0.00017180166439399324,Valid_Loss: 0.0022382510780731995
# Epoch:47/1000,Step:80/109 Train_Loss:0.0001721397289829128,Valid_Loss: 0.00223803629152038
# Epoch:47/1000,Step:100/109 Train_Loss:0.00017323179430447455,Valid_Loss: 0.002240370654662038
# Epoch:48/1000,Step:0/109 Train_Loss:0.00017073796194624774,Valid_Loss: 0.002235531608747181
# Epoch:48/1000,Step:20/109 Train_Loss:0.00017118060340498768,Valid_Loss: 0.002230202627947525
# Epoch:48/1000,Step:40/109 Train_Loss:0.00017198177795258354,Valid_Loss: 0.002235146621944075
# Epoch:48/1000,Step:60/109 Train_Loss:0.0001732376160997045,Valid_Loss: 0.002234071859828907
# Epoch:48/1000,Step:80/109 Train_Loss:0.00017322184890855523,Valid_Loss: 0.0022334969846091214
# Epoch:48/1000,Step:100/109 Train_Loss:0.00028844333317256407,Valid_Loss: 0.002231418272888259
# Epoch:49/1000,Step:0/109 Train_Loss:0.00016769252696010638,Valid_Loss: 0.002230903098760771
# Epoch:49/1000,Step:20/109 Train_Loss:0.000173935934505438,Valid_Loss: 0.0022298308692668303
# Epoch:49/1000,Step:40/109 Train_Loss:0.00045859711175268766,Valid_Loss: 0.0022237696091502337
# valid_loss decrease!!!save the model.
# Epoch:49/1000,Step:60/109 Train_Loss:0.0003657853836578262,Valid_Loss: 0.002220170035297326
# valid_loss decrease!!!save the model.
# Epoch:49/1000,Step:80/109 Train_Loss:0.00031796815534873937,Valid_Loss: 0.0022250441952608294
# Epoch:49/1000,Step:100/109 Train_Loss:0.0002885142657158059,Valid_Loss: 0.002224882447134941
# Epoch:50/1000,Step:0/109 Train_Loss:0.00015517766459258677,Valid_Loss: 0.002228692995063852
# Epoch:50/1000,Step:20/109 Train_Loss:0.00017370530081773513,Valid_Loss: 0.002230715398417311
# Epoch:50/1000,Step:40/109 Train_Loss:0.0001721716778810522,Valid_Loss: 0.0022299701273861515
# Epoch:50/1000,Step:60/109 Train_Loss:0.0001721228499170328,Valid_Loss: 0.002230390582258522
# Epoch:50/1000,Step:80/109 Train_Loss:0.00031622588312073475,Valid_Loss: 0.0022210585618345543
# Epoch:50/1000,Step:100/109 Train_Loss:0.0002886637374816258,Valid_Loss: 0.003928323523234333
# Epoch:51/1000,Step:0/109 Train_Loss:0.00017785669557774818,Valid_Loss: 0.0022258649018363557
# Epoch:51/1000,Step:20/109 Train_Loss:0.00017310530239652986,Valid_Loss: 0.002228867035545136
# Epoch:51/1000,Step:40/109 Train_Loss:0.00017151640946632286,Valid_Loss: 0.002228221857679288
# Epoch:51/1000,Step:60/109 Train_Loss:0.000363020166403972,Valid_Loss: 0.002226292805953702
# Epoch:51/1000,Step:80/109 Train_Loss:0.00031635716560293216,Valid_Loss: 0.0022210385611135066
# Epoch:51/1000,Step:100/109 Train_Loss:0.00028778605191092467,Valid_Loss: 0.002223504536227261
# Epoch:52/1000,Step:0/109 Train_Loss:0.00015537335312592958,Valid_Loss: 0.0022238847548546304
# Epoch:52/1000,Step:20/109 Train_Loss:0.0001720222979642523,Valid_Loss: 0.0022262148208324725
# Epoch:52/1000,Step:40/109 Train_Loss:0.00017054032671521036,Valid_Loss: 0.0022287088305878435
# Epoch:52/1000,Step:60/109 Train_Loss:0.0003622815216791428,Valid_Loss: 0.00221925698938
# valid_loss decrease!!!save the model.
# Epoch:52/1000,Step:80/109 Train_Loss:0.00031478576736348134,Valid_Loss: 0.002218247225784169
# valid_loss decrease!!!save the model.
# Epoch:52/1000,Step:100/109 Train_Loss:0.0002871851096345088,Valid_Loss: 0.003919398225935438
# Epoch:53/1000,Step:0/109 Train_Loss:0.000182452258579166,Valid_Loss: 0.00222435223192082
# Epoch:53/1000,Step:20/109 Train_Loss:0.00017522599516324837,Valid_Loss: 0.002235552719894553
# Epoch:53/1000,Step:40/109 Train_Loss:0.0004576205816479893,Valid_Loss: 0.002222263816719296
# Epoch:53/1000,Step:60/109 Train_Loss:0.00036526725317192007,Valid_Loss: 0.0022164589543325424
# valid_loss decrease!!!save the model.
# Epoch:53/1000,Step:80/109 Train_Loss:0.00031706799718638504,Valid_Loss: 0.0022160590131611595
# valid_loss decrease!!!save the model.
# Epoch:53/1000,Step:100/109 Train_Loss:0.00028842190487670473,Valid_Loss: 0.0022317048608567073
# Epoch:54/1000,Step:0/109 Train_Loss:0.00017044498021470951,Valid_Loss: 0.0022243265180561115
# Epoch:54/1000,Step:20/109 Train_Loss:0.0001723751734947051,Valid_Loss: 0.002220638647124091
# Epoch:54/1000,Step:40/109 Train_Loss:0.00017204571288397628,Valid_Loss: 0.00222507147077112
# Epoch:54/1000,Step:60/109 Train_Loss:0.0003651735426699237,Valid_Loss: 0.0022234962942375325
# Epoch:54/1000,Step:80/109 Train_Loss:0.0003170782700745223,Valid_Loss: 0.002217187748622489
# Epoch:54/1000,Step:100/109 Train_Loss:0.00028886347096534657,Valid_Loss: 0.002219371937057195
# Epoch:55/1000,Step:0/109 Train_Loss:0.0001601996341944948,Valid_Loss: 0.0022194877913221988
# Epoch:55/1000,Step:20/109 Train_Loss:0.00016995248349585445,Valid_Loss: 0.0022214328381255353
# Epoch:55/1000,Step:40/109 Train_Loss:0.0001725120357481094,Valid_Loss: 0.0022217262997712424
# Epoch:55/1000,Step:60/109 Train_Loss:0.00017268478343353911,Valid_Loss: 0.0022216950188092594
# Epoch:55/1000,Step:80/109 Train_Loss:0.00017256660458643455,Valid_Loss: 0.0022287549355740938
# Epoch:55/1000,Step:100/109 Train_Loss:0.00028775901958368315,Valid_Loss: 0.002227652507609023
# Epoch:56/1000,Step:0/109 Train_Loss:0.00017073556143028048,Valid_Loss: 0.0022177521931323048
# Epoch:56/1000,Step:20/109 Train_Loss:0.00017536931101838255,Valid_Loss: 0.002218054047941974
# Epoch:56/1000,Step:40/109 Train_Loss:0.0001754642299893417,Valid_Loss: 0.002219364252034075
# Epoch:56/1000,Step:60/109 Train_Loss:0.0001736612428145378,Valid_Loss: 0.0022249665840841687
# Epoch:56/1000,Step:80/109 Train_Loss:0.0003158614653148242,Valid_Loss: 0.0022194632253488772
# Epoch:56/1000,Step:100/109 Train_Loss:0.00028728709449959945,Valid_Loss: 0.002212340216141666
# valid_loss decrease!!!save the model.
# Epoch:57/1000,Step:0/109 Train_Loss:0.00016103624307351502,Valid_Loss: 0.002218577452700589
# Epoch:57/1000,Step:20/109 Train_Loss:0.0001729997589404043,Valid_Loss: 0.0022178812200865042
# Epoch:57/1000,Step:40/109 Train_Loss:0.00017471951564442456,Valid_Loss: 0.002219351675011829
# Epoch:57/1000,Step:60/109 Train_Loss:0.0001727998636870654,Valid_Loss: 0.0022214808556066403
# Epoch:57/1000,Step:80/109 Train_Loss:0.00031519573955381857,Valid_Loss: 0.0022129275079830956
# Epoch:57/1000,Step:100/109 Train_Loss:0.0002873711452142129,Valid_Loss: 0.002220144591425825
# Epoch:58/1000,Step:0/109 Train_Loss:0.00018111244260824637,Valid_Loss: 0.002213617291929286
# Epoch:58/1000,Step:20/109 Train_Loss:0.0007234887234647718,Valid_Loss: 0.0022071363224837716
# valid_loss decrease!!!save the model.
# Epoch:58/1000,Step:40/109 Train_Loss:0.00045509590501493217,Valid_Loss: 0.0022065027877146803
# valid_loss decrease!!!save the model.
# Epoch:58/1000,Step:60/109 Train_Loss:0.0003623417405336447,Valid_Loss: 0.0022096445508211046
# Epoch:58/1000,Step:80/109 Train_Loss:0.0003163769573905243,Valid_Loss: 0.0022113409692117625
# Epoch:58/1000,Step:100/109 Train_Loss:0.00028759505824543254,Valid_Loss: 0.002211129559287323
# Epoch:59/1000,Step:0/109 Train_Loss:0.00019226098481195841,Valid_Loss: 0.002212815170636657
# Epoch:59/1000,Step:20/109 Train_Loss:0.00016960293685447386,Valid_Loss: 0.002213021793898517
# Epoch:59/1000,Step:40/109 Train_Loss:0.00045461499295191323,Valid_Loss: 0.002207384370063288
# Epoch:59/1000,Step:60/109 Train_Loss:0.0003614321704748194,Valid_Loss: 0.0022115635907236923
# Epoch:59/1000,Step:80/109 Train_Loss:0.0003151644483707357,Valid_Loss: 0.0022108121776970116
# Epoch:59/1000,Step:100/109 Train_Loss:0.0002867752510257292,Valid_Loss: 0.0022130870848491497
# Epoch:60/1000,Step:0/109 Train_Loss:0.00017395474058295638,Valid_Loss: 0.0022096179161440713
# Epoch:60/1000,Step:20/109 Train_Loss:0.0001741835835462835,Valid_Loss: 0.002227248759816844
# Epoch:60/1000,Step:40/109 Train_Loss:0.00017232518057434216,Valid_Loss: 0.003912800376474346
# Epoch:60/1000,Step:60/109 Train_Loss:0.00017197048751195414,Valid_Loss: 0.002222925155352723
# Epoch:60/1000,Step:80/109 Train_Loss:0.00017193149502611657,Valid_Loss: 0.0022155330411572425
# Epoch:60/1000,Step:100/109 Train_Loss:0.00017134384210340268,Valid_Loss: 0.002214656111278066
# Epoch:61/1000,Step:0/109 Train_Loss:0.00017623877360702718,Valid_Loss: 0.0022122395247939942
# Epoch:61/1000,Step:20/109 Train_Loss:0.0001722990248458357,Valid_Loss: 0.0039023631330662857
# Epoch:61/1000,Step:40/109 Train_Loss:0.0001722806804175747,Valid_Loss: 0.0022106422086493696
# Epoch:61/1000,Step:60/109 Train_Loss:0.00017154033506580572,Valid_Loss: 0.0022096745707066443
# Epoch:61/1000,Step:80/109 Train_Loss:0.00031379597138157756,Valid_Loss: 0.002203060494998241
# valid_loss decrease!!!save the model.
# Epoch:61/1000,Step:100/109 Train_Loss:0.00028593143964915737,Valid_Loss: 0.0022056612515813875
# Epoch:62/1000,Step:0/109 Train_Loss:0.00016961795753451026,Valid_Loss: 0.0022070643768488845
# Epoch:62/1000,Step:20/109 Train_Loss:0.00017294323980159544,Valid_Loss: 0.0022099546215006236
# Epoch:62/1000,Step:40/109 Train_Loss:0.00017219055131261233,Valid_Loss: 0.0022119991878841684
# Epoch:62/1000,Step:60/109 Train_Loss:0.0001724272065568126,Valid_Loss: 0.002211341637143636
# Epoch:62/1000,Step:80/109 Train_Loss:0.0001730992704551051,Valid_Loss: 0.0022138776417390056
# Epoch:62/1000,Step:100/109 Train_Loss:0.0002871248667449282,Valid_Loss: 0.002210215489650627
# Epoch:63/1000,Step:0/109 Train_Loss:0.00018253774684200204,Valid_Loss: 0.0022037729686619086
# Epoch:63/1000,Step:20/109 Train_Loss:0.0001733291002680997,Valid_Loss: 0.002205160604596423
# Epoch:63/1000,Step:40/109 Train_Loss:0.00045203660928287557,Valid_Loss: 0.0021993637181860126
# valid_loss decrease!!!save the model.
# Epoch:63/1000,Step:60/109 Train_Loss:0.0003601593576803873,Valid_Loss: 0.0022027007822834044
# Epoch:63/1000,Step:80/109 Train_Loss:0.0003132975286459066,Valid_Loss: 0.0022026885557888468
# Epoch:63/1000,Step:100/109 Train_Loss:0.0002856644424421,Valid_Loss: 0.002205481208912876
# Epoch:64/1000,Step:0/109 Train_Loss:0.00017957630551893012,Valid_Loss: 0.0022078588533119723
# Epoch:64/1000,Step:20/109 Train_Loss:0.00016895253101077294,Valid_Loss: 0.0022138855707353805
# Epoch:64/1000,Step:40/109 Train_Loss:0.00017055813235987413,Valid_Loss: 0.0022106402384447312
# Epoch:64/1000,Step:60/109 Train_Loss:0.00017060662707106674,Valid_Loss: 0.002207933098204032
# Epoch:64/1000,Step:80/109 Train_Loss:0.00031327191238389473,Valid_Loss: 0.0022020970578112216
# Epoch:64/1000,Step:100/109 Train_Loss:0.0002861704932107169,Valid_Loss: 0.0022038405711537834
# Epoch:65/1000,Step:0/109 Train_Loss:0.00017570226359657354,Valid_Loss: 0.00220803606932903
# Epoch:65/1000,Step:20/109 Train_Loss:0.00017157120061328608,Valid_Loss: 0.002204079283647209
# Epoch:65/1000,Step:40/109 Train_Loss:0.00017220002622669406,Valid_Loss: 0.0022057538825245083
# Epoch:65/1000,Step:60/109 Train_Loss:0.00017148436603742987,Valid_Loss: 0.0022063233483312584
# Epoch:65/1000,Step:80/109 Train_Loss:0.0003147821879044877,Valid_Loss: 0.0022017507860849104
# Epoch:65/1000,Step:100/109 Train_Loss:0.0002872251274036038,Valid_Loss: 0.002207805698537158
# Epoch:66/1000,Step:0/109 Train_Loss:0.00020161438866183776,Valid_Loss: 0.0021990386883569877
# valid_loss decrease!!!save the model.
# Epoch:66/1000,Step:20/109 Train_Loss:0.00016996508686178898,Valid_Loss: 0.002202531965446134
# Epoch:66/1000,Step:40/109 Train_Loss:0.0001700850603095305,Valid_Loss: 0.002202583532074662
# Epoch:66/1000,Step:60/109 Train_Loss:0.0001715945898904548,Valid_Loss: 0.002209171352849869
# Epoch:66/1000,Step:80/109 Train_Loss:0.0003141391149107518,Valid_Loss: 0.0021959720189512278
# valid_loss decrease!!!save the model.
# Epoch:66/1000,Step:100/109 Train_Loss:0.00028528194472448464,Valid_Loss: 0.0022034647463979595
# Epoch:67/1000,Step:0/109 Train_Loss:0.0001722830717085626,Valid_Loss: 0.0022030705662976656
# Epoch:67/1000,Step:20/109 Train_Loss:0.00017545279217899017,Valid_Loss: 0.002212868748095119
# Epoch:67/1000,Step:40/109 Train_Loss:0.00045526826200868384,Valid_Loss: 0.002191812561368853
# valid_loss decrease!!!save the model.
# Epoch:67/1000,Step:60/109 Train_Loss:0.00036208975720498264,Valid_Loss: 0.0021963042514365717
# Epoch:67/1000,Step:80/109 Train_Loss:0.0003148955082498121,Valid_Loss: 0.0021989842178972182
# Epoch:67/1000,Step:100/109 Train_Loss:0.00028633451401435225,Valid_Loss: 0.002200241150835746
# Epoch:68/1000,Step:0/109 Train_Loss:0.00016582710010287833,Valid_Loss: 0.0021987317188750305
# Epoch:68/1000,Step:20/109 Train_Loss:0.0007170859633469385,Valid_Loss: 0.0022030781338539343
# Epoch:68/1000,Step:40/109 Train_Loss:0.00045026255216847294,Valid_Loss: 0.0021922616412042447
# Epoch:68/1000,Step:60/109 Train_Loss:0.0003589593613556668,Valid_Loss: 0.0021907716856621644
# valid_loss decrease!!!save the model.
# Epoch:68/1000,Step:80/109 Train_Loss:0.00031175681712783436,Valid_Loss: 0.002197030866135019
# Epoch:68/1000,Step:100/109 Train_Loss:0.00028456338895340707,Valid_Loss: 0.0022069903095827013
# Epoch:69/1000,Step:0/109 Train_Loss:0.00016276212054188035,Valid_Loss: 0.0022031820604426185
# Epoch:69/1000,Step:20/109 Train_Loss:0.00017215718074647693,Valid_Loss: 0.0021994316841600003
# Epoch:69/1000,Step:40/109 Train_Loss:0.0004531991383401179,Valid_Loss: 0.002193905868536583
# Epoch:69/1000,Step:60/109 Train_Loss:0.0003605886438262655,Valid_Loss: 0.002195512247877648
# Epoch:69/1000,Step:80/109 Train_Loss:0.0003136815652266936,Valid_Loss: 0.002196586801176668
# Epoch:69/1000,Step:100/109 Train_Loss:0.0002857806728503961,Valid_Loss: 0.002195231098568401
# Epoch:70/1000,Step:0/109 Train_Loss:0.0001771295017032264,Valid_Loss: 0.002200093209746614
# Epoch:70/1000,Step:20/109 Train_Loss:0.00017576997107885631,Valid_Loss: 0.0021983167728238905
# Epoch:70/1000,Step:40/109 Train_Loss:0.0001728416919378776,Valid_Loss: 0.002198892348672172
# Epoch:70/1000,Step:60/109 Train_Loss:0.000171487077983981,Valid_Loss: 0.002199576592164214
# Epoch:70/1000,Step:80/109 Train_Loss:0.00017069657252663636,Valid_Loss: 0.002199960554639139
# Epoch:70/1000,Step:100/109 Train_Loss:0.00028522611041980006,Valid_Loss: 0.0021929634176754455
# Epoch:71/1000,Step:0/109 Train_Loss:0.00016963852466897334,Valid_Loss: 0.0021926837823347833
# Epoch:71/1000,Step:20/109 Train_Loss:0.0001705541932389981,Valid_Loss: 0.0021961563348936184
# Epoch:71/1000,Step:40/109 Train_Loss:0.00017019404683678586,Valid_Loss: 0.002194533969533935
# Epoch:71/1000,Step:60/109 Train_Loss:0.00017015681699419932,Valid_Loss: 0.0021958339914716603
# Epoch:71/1000,Step:80/109 Train_Loss:0.00017075866206074067,Valid_Loss: 0.002201356325459433
# Epoch:71/1000,Step:100/109 Train_Loss:0.00028536470964417293,Valid_Loss: 0.0021959523076529835
# Epoch:72/1000,Step:0/109 Train_Loss:0.00017886790425106414,Valid_Loss: 0.0021886803213921565
# valid_loss decrease!!!save the model.
# Epoch:72/1000,Step:20/109 Train_Loss:0.00016920801417636937,Valid_Loss: 0.002195347224988886
# Epoch:72/1000,Step:40/109 Train_Loss:0.0001694967643686423,Valid_Loss: 0.002198435455402857
# Epoch:72/1000,Step:60/109 Train_Loss:0.0001699982889918691,Valid_Loss: 0.003874238753727925
# Epoch:72/1000,Step:80/109 Train_Loss:0.00017018804552190798,Valid_Loss: 0.0021919623518675485
# Epoch:72/1000,Step:100/109 Train_Loss:0.0001706278556907084,Valid_Loss: 0.0038802376019433844
# Epoch:73/1000,Step:0/109 Train_Loss:0.00016756821792901676,Valid_Loss: 0.0021987462543313725
# Epoch:73/1000,Step:20/109 Train_Loss:0.00017279828466319034,Valid_Loss: 0.002188107348924378
# valid_loss decrease!!!save the model.
# Epoch:73/1000,Step:40/109 Train_Loss:0.00017018302437725842,Valid_Loss: 0.002188962491833081
# Epoch:73/1000,Step:60/109 Train_Loss:0.00017147332602152483,Valid_Loss: 0.0021919856773240007
# Epoch:73/1000,Step:80/109 Train_Loss:0.00017081817311508636,Valid_Loss: 0.002199730622664904
# Epoch:73/1000,Step:100/109 Train_Loss:0.00028451922324891946,Valid_Loss: 0.002192767833411955
# Epoch:74/1000,Step:0/109 Train_Loss:0.0001846396169524816,Valid_Loss: 0.0021905948671734022
# Epoch:74/1000,Step:20/109 Train_Loss:0.0001707614785276122,Valid_Loss: 0.0038679671210516747
# Epoch:74/1000,Step:40/109 Train_Loss:0.00017017089240785769,Valid_Loss: 0.0021926947579891504
# Epoch:74/1000,Step:60/109 Train_Loss:0.00017033646652794563,Valid_Loss: 0.0021914667812488
# Epoch:74/1000,Step:80/109 Train_Loss:0.00017095113028489813,Valid_Loss: 0.002195181894480407
# Epoch:74/1000,Step:100/109 Train_Loss:0.0002851990704321844,Valid_Loss: 0.0021906675528941145
# Epoch:75/1000,Step:0/109 Train_Loss:0.0001658564096884432,Valid_Loss: 0.002186340074938732
# valid_loss decrease!!!save the model.
# Epoch:75/1000,Step:20/109 Train_Loss:0.0007147939559228558,Valid_Loss: 0.0021789318963529496
# valid_loss decrease!!!save the model.
# Epoch:75/1000,Step:40/109 Train_Loss:0.0004512737221210448,Valid_Loss: 0.0038478070105532466
# Epoch:75/1000,Step:60/109 Train_Loss:0.0003582874340696473,Valid_Loss: 0.002185884307821935
# Epoch:75/1000,Step:80/109 Train_Loss:0.000312619302281655,Valid_Loss: 0.002183122674535432
# Epoch:75/1000,Step:100/109 Train_Loss:0.00028452145736255867,Valid_Loss: 0.0021871080198951347
# Epoch:76/1000,Step:0/109 Train_Loss:0.0001728130092531272,Valid_Loss: 0.002189257137460804
# Epoch:76/1000,Step:20/109 Train_Loss:0.0001721996010703692,Valid_Loss: 0.002189535740877235
# Epoch:76/1000,Step:40/109 Train_Loss:0.00017159345233186442,Valid_Loss: 0.002190775241225266
# Epoch:76/1000,Step:60/109 Train_Loss:0.00035978165430925423,Valid_Loss: 0.002182265592120546
# Epoch:76/1000,Step:80/109 Train_Loss:0.0003128504001872563,Valid_Loss: 0.002179719285044097
# Epoch:76/1000,Step:100/109 Train_Loss:0.00028450947193939724,Valid_Loss: 0.00218396060992214
# Epoch:77/1000,Step:0/109 Train_Loss:0.00017952373320890284,Valid_Loss: 0.002187166676757256
# Epoch:77/1000,Step:20/109 Train_Loss:0.0001711156678317828,Valid_Loss: 0.0021861723875129624
# Epoch:77/1000,Step:40/109 Train_Loss:0.00045011565958029393,Valid_Loss: 0.002179746596074693
# Epoch:77/1000,Step:60/109 Train_Loss:0.00035887371060832436,Valid_Loss: 0.0021772940887244134
# valid_loss decrease!!!save the model.
# Epoch:77/1000,Step:80/109 Train_Loss:0.000312891893073037,Valid_Loss: 0.0021825026834645213
# Epoch:77/1000,Step:100/109 Train_Loss:0.00028521084445034585,Valid_Loss: 0.0038550294512608905
# Epoch:78/1000,Step:0/109 Train_Loss:0.00017935139324318583,Valid_Loss: 0.0021841503645376663
# Epoch:78/1000,Step:20/109 Train_Loss:0.0001708306902824734,Valid_Loss: 0.0038597462457151802
# Epoch:78/1000,Step:40/109 Train_Loss:0.00017129048758461976,Valid_Loss: 0.0021874707610253443
# Epoch:78/1000,Step:60/109 Train_Loss:0.0001724998392896646,Valid_Loss: 0.002191689765513465
# Epoch:78/1000,Step:80/109 Train_Loss:0.00017188238977065596,Valid_Loss: 0.00218931335709041
# Epoch:78/1000,Step:100/109 Train_Loss:0.0002843736832423878,Valid_Loss: 0.0021841266397940196
# Epoch:79/1000,Step:0/109 Train_Loss:0.00015434286007736037,Valid_Loss: 0.0021830458741417405
# Epoch:79/1000,Step:20/109 Train_Loss:0.0001712141285013713,Valid_Loss: 0.0021861226050944814
# Epoch:79/1000,Step:40/109 Train_Loss:0.0001718212487966455,Valid_Loss: 0.0021820553494371077
# Epoch:79/1000,Step:60/109 Train_Loss:0.00017079587167722203,Valid_Loss: 0.002185535551426244
# Epoch:79/1000,Step:80/109 Train_Loss:0.00017083001993620255,Valid_Loss: 0.0021874500487680314
# Epoch:79/1000,Step:100/109 Train_Loss:0.00028352137280263003,Valid_Loss: 0.002179224731462168
# Epoch:80/1000,Step:0/109 Train_Loss:0.00016001540901192446,Valid_Loss: 0.0021779616975418337
# Epoch:80/1000,Step:20/109 Train_Loss:0.00017418921699762928,Valid_Loss: 0.00218288443953027
# Epoch:80/1000,Step:40/109 Train_Loss:0.00017288827459761014,Valid_Loss: 0.0021827575569875624
# Epoch:80/1000,Step:60/109 Train_Loss:0.00017217022784980215,Valid_Loss: 0.0021872532526638006
# Epoch:80/1000,Step:80/109 Train_Loss:0.0003124332503521488,Valid_Loss: 0.0021767702052184813
# valid_loss decrease!!!save the model.
# Epoch:80/1000,Step:100/109 Train_Loss:0.0002843273995750314,Valid_Loss: 0.002181675375652329
# Epoch:81/1000,Step:0/109 Train_Loss:0.00016698441186370494,Valid_Loss: 0.0021827070234377347
# Epoch:81/1000,Step:20/109 Train_Loss:0.00016896975543997535,Valid_Loss: 0.002183065245718999
# Epoch:81/1000,Step:40/109 Train_Loss:0.00044859762140893295,Valid_Loss: 0.0038384178031992183
# Epoch:81/1000,Step:60/109 Train_Loss:0.00035887128238610796,Valid_Loss: 0.002175597337855163
# valid_loss decrease!!!save the model.
# Epoch:81/1000,Step:80/109 Train_Loss:0.0003127261283738127,Valid_Loss: 0.002174101867930074
# valid_loss decrease!!!save the model.
# Epoch:81/1000,Step:100/109 Train_Loss:0.00028508804789244773,Valid_Loss: 0.0021747973630691763
# Epoch:82/1000,Step:0/109 Train_Loss:0.00016111304806273188,Valid_Loss: 0.0021771420174396287
# Epoch:82/1000,Step:20/109 Train_Loss:0.0001696024102169618,Valid_Loss: 0.0021792663087104535
# Epoch:82/1000,Step:40/109 Train_Loss:0.0004461315367144628,Valid_Loss: 0.0021694822689187466
# valid_loss decrease!!!save the model.
# Epoch:82/1000,Step:60/109 Train_Loss:0.00035648586754716575,Valid_Loss: 0.002172067080469054
# Epoch:82/1000,Step:80/109 Train_Loss:0.00031087570981713845,Valid_Loss: 0.0021757376245370172
# ...
# Epoch:294/1000,Step:40/109 Train_Loss:0.00040176288250701577,Valid_Loss: 0.001912913282015219
# valid_loss decrease!!!save the model.
# Epoch:294/1000,Step:60/109 Train_Loss:0.00032471893739928264,Valid_Loss: 0.001922505122775969
# Epoch:294/1000,Step:80/109 Train_Loss:0.0002848930786144132,Valid_Loss: 0.001920205652985962
# Epoch:294/1000,Step:100/109 Train_Loss:0.0002608287549772741,Valid_Loss: 0.0019316215927319314
# Epoch:295/1000,Step:0/109 Train_Loss:0.00016225801138961807,Valid_Loss: 0.0019222674157382855
# Epoch:295/1000,Step:20/109 Train_Loss:0.0006220707052005832,Valid_Loss: 0.00191701582871948
# Epoch:295/1000,Step:40/109 Train_Loss:0.0003994367716424059,Valid_Loss: 0.0019162464146633717
# Epoch:295/1000,Step:60/109 Train_Loss:0.0003223488747689117,Valid_Loss: 0.001919434885200419
# Epoch:295/1000,Step:80/109 Train_Loss:0.00028296044296567506,Valid_Loss: 0.001920786267595612
# Epoch:295/1000,Step:100/109 Train_Loss:0.0002602422146097018,Valid_Loss: 0.0019209223147998264
# Epoch:296/1000,Step:0/109 Train_Loss:0.00016545415435679142,Valid_Loss: 0.0019226263079919726
# Epoch:296/1000,Step:20/109 Train_Loss:0.00016877444350458368,Valid_Loss: 0.0019217991319881477
# Epoch:296/1000,Step:40/109 Train_Loss:0.00040054654719160203,Valid_Loss: 0.0019201631413589806
# Epoch:296/1000,Step:60/109 Train_Loss:0.00032432649624958537,Valid_Loss: 0.0019328668332549068
# Epoch:296/1000,Step:80/109 Train_Loss:0.00028486887270445614,Valid_Loss: 0.0019170921144326775
# Epoch:296/1000,Step:100/109 Train_Loss:0.00026098148154837255,Valid_Loss: 0.001915728566093091
# Epoch:297/1000,Step:0/109 Train_Loss:0.000154271198226458,Valid_Loss: 0.0019199847257125046
# Epoch:297/1000,Step:20/109 Train_Loss:0.00016365087284870889,Valid_Loss: 0.0019203094630022692
# Epoch:297/1000,Step:40/109 Train_Loss:0.00016488765393604565,Valid_Loss: 0.0019230094280411178
# Epoch:297/1000,Step:60/109 Train_Loss:0.00016586821398245242,Valid_Loss: 0.0019239699920899495
# Epoch:297/1000,Step:80/109 Train_Loss:0.00028494076402774625,Valid_Loss: 0.0019224353364104233
# Epoch:297/1000,Step:100/109 Train_Loss:0.00026096351664910714,Valid_Loss: 0.0019159833522020369
# Epoch:298/1000,Step:0/109 Train_Loss:0.0001661219174086924,Valid_Loss: 0.0019149983163612744
# Epoch:298/1000,Step:20/109 Train_Loss:0.0001679844409230865,Valid_Loss: 0.0019207594224765433
# Epoch:298/1000,Step:40/109 Train_Loss:0.00016568945603284281,Valid_Loss: 0.0019213752336033876
# Epoch:298/1000,Step:60/109 Train_Loss:0.00016502534696002672,Valid_Loss: 0.0019270798048460305
# Epoch:298/1000,Step:80/109 Train_Loss:0.0001647222561557916,Valid_Loss: 0.0019255693035726232
# Epoch:298/1000,Step:100/109 Train_Loss:0.0002604907613418413,Valid_Loss: 0.00191622992534996
# Epoch:299/1000,Step:0/109 Train_Loss:0.00017087069049461092,Valid_Loss: 0.0019173203553262987
# Epoch:299/1000,Step:20/109 Train_Loss:0.0001670697088250668,Valid_Loss: 0.0019182124755480466
# Epoch:299/1000,Step:40/109 Train_Loss:0.00040134753120243857,Valid_Loss: 0.001909304761406874
# valid_loss decrease!!!save the model.
# Epoch:299/1000,Step:60/109 Train_Loss:0.0003241044843152679,Valid_Loss: 0.0019134457489202175
# Epoch:299/1000,Step:80/109 Train_Loss:0.00028549871695133795,Valid_Loss: 0.0019169022141938869
# Epoch:299/1000,Step:100/109 Train_Loss:0.00026140460669692725,Valid_Loss: 0.0019162297916096248
# Epoch:300/1000,Step:0/109 Train_Loss:0.0001608179090574279,Valid_Loss: 0.0019176487050411599
# Epoch:300/1000,Step:20/109 Train_Loss:0.0001657704058006468,Valid_Loss: 0.0019207929825624432
# Epoch:300/1000,Step:40/109 Train_Loss:0.0001650958635711604,Valid_Loss: 0.0019178281203255192
# Epoch:300/1000,Step:60/109 Train_Loss:0.00016471213081063963,Valid_Loss: 0.0019257021422345775
# Epoch:300/1000,Step:80/109 Train_Loss:0.00016412667495210802,Valid_Loss: 0.0019186928386176986
# Epoch:300/1000,Step:100/109 Train_Loss:0.00025987547885050115,Valid_Loss: 0.0019186963547551535
# Epoch:301/1000,Step:0/109 Train_Loss:0.00015581639334653422,Valid_Loss: 0.0019176598393615973
# Epoch:301/1000,Step:20/109 Train_Loss:0.0001629539909181602,Valid_Loss: 0.0019164385419136773
# Epoch:301/1000,Step:40/109 Train_Loss:0.00016320291222699914,Valid_Loss: 0.001917154986969929
# Epoch:301/1000,Step:60/109 Train_Loss:0.0003217070899027533,Valid_Loss: 0.0019105085105388668
# Epoch:301/1000,Step:80/109 Train_Loss:0.0002833696044685207,Valid_Loss: 0.0019131516698890944
# Epoch:301/1000,Step:100/109 Train_Loss:0.00025979272379151377,Valid_Loss: 0.0019162413443240642
# Epoch:302/1000,Step:0/109 Train_Loss:0.0001612517784062626,Valid_Loss: 0.001916271094690029
# Epoch:302/1000,Step:20/109 Train_Loss:0.0001652920516902409,Valid_Loss: 0.0019151088297999763
# Epoch:302/1000,Step:40/109 Train_Loss:0.0001646879315680604,Valid_Loss: 0.001916725271163303
# Epoch:302/1000,Step:60/109 Train_Loss:0.00016442429497264804,Valid_Loss: 0.0019203605996086098
# Epoch:302/1000,Step:80/109 Train_Loss:0.00016506521415600314,Valid_Loss: 0.0019189252845773512
# Epoch:302/1000,Step:100/109 Train_Loss:0.0001647722748329631,Valid_Loss: 0.0019187690733274156
# Epoch:303/1000,Step:0/109 Train_Loss:0.00018084116115151384,Valid_Loss: 0.00191573009040753
# Epoch:303/1000,Step:20/109 Train_Loss:0.00016539721332788608,Valid_Loss: 0.001913590474700333
# Epoch:303/1000,Step:40/109 Train_Loss:0.00039770756632346416,Valid_Loss: 0.0019055871386494273
# valid_loss decrease!!!save the model.
# Epoch:303/1000,Step:60/109 Train_Loss:0.0003220291192637575,Valid_Loss: 0.0019074374879929873
# Epoch:303/1000,Step:80/109 Train_Loss:0.00028297916671043657,Valid_Loss: 0.001909164649178924
# Epoch:303/1000,Step:100/109 Train_Loss:0.0002596288049683156,Valid_Loss: 0.0019087436160337577
# Epoch:304/1000,Step:0/109 Train_Loss:0.0001561412493688478,Valid_Loss: 0.001910901958308333
# Epoch:304/1000,Step:20/109 Train_Loss:0.0001663219521252399,Valid_Loss: 0.0019112766780484873
# Epoch:304/1000,Step:40/109 Train_Loss:0.00016622735372615792,Valid_Loss: 0.0019116923609822218
# Epoch:304/1000,Step:60/109 Train_Loss:0.000322788424508662,Valid_Loss: 0.0019096654070964933
# Epoch:304/1000,Step:80/109 Train_Loss:0.0002828324676315049,Valid_Loss: 0.0019073727211460932
# Epoch:304/1000,Step:100/109 Train_Loss:0.0002593779902722726,Valid_Loss: 0.0019091429160855
# Epoch:305/1000,Step:0/109 Train_Loss:0.00015490646505535405,Valid_Loss: 0.001909240422590528
# Epoch:305/1000,Step:20/109 Train_Loss:0.0001629869462808457,Valid_Loss: 0.0019135590105831045
# Epoch:305/1000,Step:40/109 Train_Loss:0.0003995617776713335,Valid_Loss: 0.0019152920232225672
# Epoch:305/1000,Step:60/109 Train_Loss:0.00032280576726938015,Valid_Loss: 0.0019094055012488637
# Epoch:305/1000,Step:80/109 Train_Loss:0.00028335560942685615,Valid_Loss: 0.001908609340179054
# Epoch:305/1000,Step:100/109 Train_Loss:0.0002602205657026354,Valid_Loss: 0.0019083140973466916
# Epoch:306/1000,Step:0/109 Train_Loss:0.00015994526813428015,Valid_Loss: 0.001913646304867766
# Epoch:306/1000,Step:20/109 Train_Loss:0.0001656539736239315,Valid_Loss: 0.001913971432135939
# Epoch:306/1000,Step:40/109 Train_Loss:0.0001647124921009784,Valid_Loss: 0.0033623195756134192
# Epoch:306/1000,Step:60/109 Train_Loss:0.00016450041307181684,Valid_Loss: 0.0019131762960552749
# Epoch:306/1000,Step:80/109 Train_Loss:0.00028252780319536685,Valid_Loss: 0.001910109657897896
# Epoch:306/1000,Step:100/109 Train_Loss:0.0002594333881169956,Valid_Loss: 0.001912437402391726
# Epoch:307/1000,Step:0/109 Train_Loss:0.00016403578260289838,Valid_Loss: 0.0019138727247693225
# Epoch:307/1000,Step:20/109 Train_Loss:0.0001655746304110146,Valid_Loss: 0.0019176200975431676
# Epoch:307/1000,Step:40/109 Train_Loss:0.00039948788408717957,Valid_Loss: 0.0019053958893404687
# valid_loss decrease!!!save the model.
# Epoch:307/1000,Step:60/109 Train_Loss:0.0003227419993150558,Valid_Loss: 0.0019047104469766467
# valid_loss decrease!!!save the model.
# Epoch:307/1000,Step:80/109 Train_Loss:0.00028430385354984535,Valid_Loss: 0.0019094481572220269
# Epoch:307/1000,Step:100/109 Train_Loss:0.0002606672345394854,Valid_Loss: 0.0033575629452629045
# Epoch:308/1000,Step:0/109 Train_Loss:0.00016568217277015948,Valid_Loss: 0.0019096712159084944
# Epoch:308/1000,Step:20/109 Train_Loss:0.00016453805226592565,Valid_Loss: 0.001909326237039331
# Epoch:308/1000,Step:40/109 Train_Loss:0.00016420916936743825,Valid_Loss: 0.001912840858478135
# Epoch:308/1000,Step:60/109 Train_Loss:0.0001632837168725247,Valid_Loss: 0.0019129393880533857
# Epoch:308/1000,Step:80/109 Train_Loss:0.00016311670122766398,Valid_Loss: 0.0019146690935884297
# Epoch:308/1000,Step:100/109 Train_Loss:0.0002587007346133844,Valid_Loss: 0.0019147720770887977
# Epoch:309/1000,Step:0/109 Train_Loss:0.00015761072104228662,Valid_Loss: 0.0019079135535782295
# Epoch:309/1000,Step:20/109 Train_Loss:0.0001597166424349594,Valid_Loss: 0.00190737442739238
# Epoch:309/1000,Step:40/109 Train_Loss:0.00016169508645779,Valid_Loss: 0.0019081390624111744
# Epoch:309/1000,Step:60/109 Train_Loss:0.00031915450827900606,Valid_Loss: 0.0019003976221103037
# valid_loss decrease!!!save the model.
# Epoch:309/1000,Step:80/109 Train_Loss:0.0002807944798390678,Valid_Loss: 0.001908697999504683
# Epoch:309/1000,Step:100/109 Train_Loss:0.00025814669219888367,Valid_Loss: 0.0019186083324041075
# Epoch:310/1000,Step:0/109 Train_Loss:0.0001780264063910533,Valid_Loss: 0.0033558816625178438
# Epoch:310/1000,Step:20/109 Train_Loss:0.00016772853067720912,Valid_Loss: 0.001907867929076585
# Epoch:310/1000,Step:40/109 Train_Loss:0.0004005128545666542,Valid_Loss: 0.001901084004113735
# Epoch:310/1000,Step:60/109 Train_Loss:0.00032285902096080475,Valid_Loss: 0.0019088064894317084
# Epoch:310/1000,Step:80/109 Train_Loss:0.00028418420012782885,Valid_Loss: 0.001909309759412021
# Epoch:310/1000,Step:100/109 Train_Loss:0.00026051131198089045,Valid_Loss: 0.0019069764281795776
# Epoch:311/1000,Step:0/109 Train_Loss:0.00015923997372077,Valid_Loss: 0.0019198442016477575
# Epoch:311/1000,Step:20/109 Train_Loss:0.00016719473549826682,Valid_Loss: 0.0019076098502803294
# Epoch:311/1000,Step:40/109 Train_Loss:0.00016538818352380367,Valid_Loss: 0.0019121973080517328
# Epoch:311/1000,Step:60/109 Train_Loss:0.00016586568273759594,Valid_Loss: 0.0019219063468467496
# Epoch:311/1000,Step:80/109 Train_Loss:0.00016478995211704616,Valid_Loss: 0.0019121480596513613
# Epoch:311/1000,Step:100/109 Train_Loss:0.00016400253992446961,Valid_Loss: 0.0019128811340008457
# Epoch:312/1000,Step:0/109 Train_Loss:0.0001625048363465901,Valid_Loss: 0.001904632695954646
# Epoch:312/1000,Step:20/109 Train_Loss:0.00016557626805715128,Valid_Loss: 0.0019048171377947806
# Epoch:312/1000,Step:40/109 Train_Loss:0.00016345703634877007,Valid_Loss: 0.0019055586164637638
# Epoch:312/1000,Step:60/109 Train_Loss:0.00016446332196137415,Valid_Loss: 0.0019108492574407318
# Epoch:312/1000,Step:80/109 Train_Loss:0.0002823910080100046,Valid_Loss: 0.0019141699719287238
# Epoch:312/1000,Step:100/109 Train_Loss:0.0002593905060484967,Valid_Loss: 0.0019037795497632236
# Epoch:313/1000,Step:0/109 Train_Loss:0.00016126853264051254,Valid_Loss: 0.0019135914463831328
# Epoch:313/1000,Step:20/109 Train_Loss:0.00016497634897209807,Valid_Loss: 0.0019031176798914272
# Epoch:313/1000,Step:40/109 Train_Loss:0.00016413326638747911,Valid_Loss: 0.0019029116689776688
# Epoch:313/1000,Step:60/109 Train_Loss:0.00016310109471761393,Valid_Loss: 0.001914236826220283
# Epoch:313/1000,Step:80/109 Train_Loss:0.00028160965962610227,Valid_Loss: 0.0018992893220414592
# valid_loss decrease!!!save the model.
# Epoch:313/1000,Step:100/109 Train_Loss:0.00025887114858154077,Valid_Loss: 0.0019012240999922918
# Epoch:314/1000,Step:0/109 Train_Loss:0.0001635320960683583,Valid_Loss: 0.0019018841557702593
# Epoch:314/1000,Step:20/109 Train_Loss:0.0001618910325330844,Valid_Loss: 0.0019009663915993157
# Epoch:314/1000,Step:40/109 Train_Loss:0.00039366166125179536,Valid_Loss: 0.001899301042325334
# Epoch:314/1000,Step:60/109 Train_Loss:0.00031906087559640834,Valid_Loss: 0.0019008699288779179
# Epoch:314/1000,Step:80/109 Train_Loss:0.00028123964765246017,Valid_Loss: 0.0019019311464653194
# Epoch:314/1000,Step:100/109 Train_Loss:0.0002584916262518429,Valid_Loss: 0.001901169949243876
# Epoch:315/1000,Step:0/109 Train_Loss:0.00015302232033761955,Valid_Loss: 0.0019024223189769347
# Epoch:315/1000,Step:20/109 Train_Loss:0.00016361439922850377,Valid_Loss: 0.0019004626661171338
# Epoch:315/1000,Step:40/109 Train_Loss:0.00016353147781379324,Valid_Loss: 0.0019061840067014836
# Epoch:315/1000,Step:60/109 Train_Loss:0.00016446075854267825,Valid_Loss: 0.001905562982832968
# Epoch:315/1000,Step:80/109 Train_Loss:0.00028198645061869564,Valid_Loss: 0.0018984593164532576
# valid_loss decrease!!!save the model.
# Epoch:315/1000,Step:100/109 Train_Loss:0.00025847840767178286,Valid_Loss: 0.0033409073503665354
# Epoch:316/1000,Step:0/109 Train_Loss:0.00015073997515046412,Valid_Loss: 0.0018993048023553149
# Epoch:316/1000,Step:20/109 Train_Loss:0.00016374656460955273,Valid_Loss: 0.0019030891376607998
# Epoch:316/1000,Step:40/109 Train_Loss:0.00016289906421949592,Valid_Loss: 0.0019092398900729718
# Epoch:316/1000,Step:60/109 Train_Loss:0.0001642730865051267,Valid_Loss: 0.0019049485346308767
# Epoch:316/1000,Step:80/109 Train_Loss:0.00016368463118068252,Valid_Loss: 0.0019047211103883418
# Epoch:316/1000,Step:100/109 Train_Loss:0.00025783794874868554,Valid_Loss: 0.0033421550201541213
# Epoch:317/1000,Step:0/109 Train_Loss:0.00016980771670429916,Valid_Loss: 0.001900101653494343
# Epoch:317/1000,Step:20/109 Train_Loss:0.00062073082950998,Valid_Loss: 0.0018970099789138884
# valid_loss decrease!!!save the model.
# Epoch:317/1000,Step:40/109 Train_Loss:0.00039746235796877133,Valid_Loss: 0.0018962184021069967
# valid_loss decrease!!!save the model.
# Epoch:317/1000,Step:60/109 Train_Loss:0.0003206853770508295,Valid_Loss: 0.0019118977912979383
# Epoch:317/1000,Step:80/109 Train_Loss:0.0002824463617791842,Valid_Loss: 0.0033423441195255727
# Epoch:317/1000,Step:100/109 Train_Loss:0.00025868262730561727,Valid_Loss: 0.0019014167738546524
# Epoch:318/1000,Step:0/109 Train_Loss:0.00016704844495714428,Valid_Loss: 0.0018996507452916716
# Epoch:318/1000,Step:20/109 Train_Loss:0.0001614744724428712,Valid_Loss: 0.0033435392299538693
# Epoch:318/1000,Step:40/109 Train_Loss:0.00016043488461733125,Valid_Loss: 0.0019114889527888973
# Epoch:318/1000,Step:60/109 Train_Loss:0.00016208455680179516,Valid_Loss: 0.0019025139861218138
# Epoch:318/1000,Step:80/109 Train_Loss:0.00016297907891997906,Valid_Loss: 0.0019072255387089178
# Epoch:318/1000,Step:100/109 Train_Loss:0.00025751974566562804,Valid_Loss: 0.001896685804705189
# Epoch:319/1000,Step:0/109 Train_Loss:0.00016534917402031668,Valid_Loss: 0.0018973657662893439
# Epoch:319/1000,Step:20/109 Train_Loss:0.0001634192959491692,Valid_Loss: 0.0018988685911929635
# Epoch:319/1000,Step:40/109 Train_Loss:0.00016225615229012943,Valid_Loss: 0.0019016117174996332
# Epoch:319/1000,Step:60/109 Train_Loss:0.0003205194581135837,Valid_Loss: 0.0019030237819519945
# Epoch:319/1000,Step:80/109 Train_Loss:0.0002821003511920164,Valid_Loss: 0.0018928914517764063
# valid_loss decrease!!!save the model.
# Epoch:319/1000,Step:100/109 Train_Loss:0.00025892292949087476,Valid_Loss: 0.0018973832738352924
# Epoch:320/1000,Step:0/109 Train_Loss:0.0001547649030466069,Valid_Loss: 0.0018972647559740955
# Epoch:320/1000,Step:20/109 Train_Loss:0.0006188650527354864,Valid_Loss: 0.001890308823780109
# valid_loss decrease!!!save the model.
# Epoch:320/1000,Step:40/109 Train_Loss:0.0003973829616619367,Valid_Loss: 0.0018912046169635073
# Epoch:320/1000,Step:60/109 Train_Loss:0.00032087711938616606,Valid_Loss: 0.0019030545156172953
# Epoch:320/1000,Step:80/109 Train_Loss:0.00028197496601753554,Valid_Loss: 0.0018951893890648572
# Epoch:320/1000,Step:100/109 Train_Loss:0.0002586472093750075,Valid_Loss: 0.0018983578641859832
# Epoch:321/1000,Step:0/109 Train_Loss:0.00015973023312419604,Valid_Loss: 0.0019073092322444674
# Epoch:321/1000,Step:20/109 Train_Loss:0.00016382142430692196,Valid_Loss: 0.0033370227987416312
# Epoch:321/1000,Step:40/109 Train_Loss:0.00016311634353871932,Valid_Loss: 0.001898635066323146
# Epoch:321/1000,Step:60/109 Train_Loss:0.0001635710989529993,Valid_Loss: 0.0019063144458599992

# %%
def calcu_XY(predY):
    #input: [batchsize len features]; features:[velx,vely,x,y]
    '''
    deltaY = v0*delta_t + 0.5* a *delta_t^2
    a = (v - v0)/delta_t
    vo
    '''
    vels = predY[:,:,0:2]
    rst_xy = np.zeros(predY[:,:,0:2].shape)
    rst_xy[:,:-predict_length,:] = predY[:,:-predict_length,2:4]
    delta_t = 0.1
   
    for i in range(predict_length):
        a = (vels[:,-(predict_length-i),:] - vels[:,-(predict_length+1-i),:])/delta_t
        delta_xy = vels[:,-(predict_length-i),:]*vels[:,-(predict_length-i),:]-vels[:,-(predict_length+1-i),:]*vels[:,-(predict_length+1-i),:]
        delta_xy = delta_xy/(2*a)
        rst_xy[:,-(predict_length-i),:] = rst_xy[:,-(predict_length+1-i),:] + delta_xy
    """
    for i in range(1,100):
        a = (vels[:,i,:] - vels[:,i-1,:])/delta_t
        delta_xy = vels[:,i,:]*vels[:,i-1,:]-vels[:,i-1,:]*vels[:,i-1,:]
        delta_xy = delta_xy/(2*a)
        rst_xy[:,i,:] = rst_xy[:,i-1,:] + delta_xy
       """
    t = rst_xy-predY[:,:,2:4]
    #print(rst_xy)
    #print(t[1,:,:])
    return rst_xy

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.show()

# %%
def Eval_net(encoder):
    n_trajectory_batch = 0
    loss = []
    for local_batch, local_labels in Test:
        n_trajectory_batch = n_trajectory_batch + 1
        criterion = nn.MSELoss()
        local_batch = local_batch.to(device)
        local_labels = local_labels.to(device)
        predY = encoder(local_batch)
        #print(WholeSet.std.repeat(BatchSize,100,1).shape)
        test_loss = criterion(predY,local_labels)
        loss.append(test_loss.item())
        std = WholeSet.std.repeat(local_batch.shape[0],x.shape[1],1)
        std = std[:,:,:4].to(device)
        mn = WholeSet.mn.repeat(local_batch.shape[0],x.shape[1],1)
        mn = mn[:,:,:4].to(device)
        rg = WholeSet.range.repeat(local_batch.shape[0],x.shape[1],1)
        rg = rg[:,:,:4].to(device)
        predY = (predY*(rg*std)+mn).detach().cpu()
        pY = np.array(predY )
        pY =  scipy.signal.savgol_filter(pY, window_length=((x.shape[1]-11)//2)*2+1, polyorder=3,axis=1)
        local_labels = (local_labels*(rg*std)+mn).detach().cpu()
        Y = np.array(local_labels)
        pY[:,:-predict_length,:] = Y[:,:-predict_length,:]
        rst_xy = calcu_XY(pY)
        if n_trajectory_batch > 20:
            break
        for i in range(1):
            #plt.figure(i)
            #plt.xlim(0,80)
            #plt.ylim(0,2000)
            #plt.subplot(4,5,n_trajectory_batch)
            plt.plot(pY[i,:,2],pY[i,:,3],'r',label='prediction')
            plt.plot(Y[i,:,2],Y[i,:,3],'g',label='actual')
            plt.plot(rst_xy[i,:,0],rst_xy[i,:,1],'b',label='rst_xy')
            plt.legend()
        plt.show()
        print('Test loss:',test_loss.item())
    print('average loss:',np.mean(loss))

# %%
hidden_size = 256
Prednet = NNPred(x.shape[2], y.shape[2],hidden_size, x.shape[0])
Prednet.load_state_dict(torch.load('model/trajectory_predict_68_4_30.pt'))
Prednet = Prednet.double()
Prednet = Prednet.to(device)
Prednet.eval()
Eval_net(Prednet)
# Out:
# Test loss: 0.00022073959644564948
# Test loss: 0.00016674021564884803
# Test loss: 0.00020541856129430668
# Test loss: 0.0002692255691242666
# Test loss: 0.0002898690604054518
# Test loss: 0.00017433108234597347
# Test loss: 0.00022139632598692444
# Test loss: 0.00024220407149262927
# Test loss: 0.0004975680267164633
# Test loss: 0.000390800777664272
# Test loss: 0.00028593373910693076
# Test loss: 0.0005440103956227111
# Test loss: 0.0002019871015541837
# Test loss: 0.00020357420023781777
# average loss: 0.00027955705168903065

# %%
def predict(model,test_load,n):
    test = iter(test_load)
    x,y =  test.next()
    x,y = x.to(device),y.to(device)
    predY = model(x)
    criterion = nn.MSELoss()
    test_loss = criterion(predY,y)
    std = WholeSet.std.repeat(x.shape[0],x.shape[1],1)
    std = std[:,:,:4].to(device)
    mn = WholeSet.mn.repeat(x.shape[0],x.shape[1],1)
    mn = mn[:,:,:4].to(device)
    rg = WholeSet.range.repeat(x.shape[0],x.shape[1],1)
    rg = rg[:,:,:4].to(device)
    predY = (predY*(rg*std)+mn).detach().cpu()
    pY = np.array(predY)
    pY =  scipy.signal.savgol_filter(pY, window_length=((x.shape[1]-11)//2)*2+1, polyorder=3,axis=1)
    local_labels = (y*(rg*std)+mn).detach().cpu()
    Y = np.array(local_labels)
    pY[:,:-predict_length,:] = Y[:,:-predict_length,:]
    rst_xy = calcu_XY(pY)
    #rst_xy =  scipy.signal.savgol_filter(rst_xy, window_length=31, polyorder=3,axis=1)
    #rst_xy[:,-30:-1,:]=  scipy.signal.savgol_filter(rst_xy[:,-30:-1,:], window_length=51, polyorder=3,axis=0)
    plt.plot(rst_xy[:n,:,0][0],rst_xy[:n,:,1][0],'b',label="rst_xy")
    plt.plot(pY[:n,:,2][0],pY[:n,:,3][0],'r',label='prediction')
    plt.plot(Y[:n,:,2][0],Y[:n,:,3][0],'g',label='actual')
    plt.legend()
    print("Test Loss:",test_loss.item())

# %%
hidden_size = 256
Prednet = NNPred(x.shape[2], y.shape[2],hidden_size, x.shape[0])
Prednet.load_state_dict(torch.load('model/trajectory_predict_68_4_30.pt'))
Prednet = Prednet.double()
Prednet = Prednet.to(device)
Prednet.eval()
predict(Prednet,Test,1)
# Out:
# Test Loss: 0.00026646715623146895

# %%
test_iter = iter(Test)
x, y = test_iter.next()
print(x.shape)
x,y = x.to(device),y.to(device)
x = x[0][0].view(-1,len(x[0][0])).unsqueeze(0)
predY = Prednet(x)
print(predY)
print(y[0][2])
# Out:
# torch.Size([128, 100, 68])
# tensor([[[ 0.2781, -0.1984, -0.0295,  0.6421]]], device='cuda:0',
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor([ 0.1809,  1.7650, -0.0526,  0.7197], device='cuda:0',
#        dtype=torch.float64)

# %% [markdown]
# #下面使用行为预测模型加轨迹预测模型预测轨迹。

# %%
from behavior_model import LSTM
def compute_label(input_x):
    std = WholeSet.std.repeat(x.shape[0],x.shape[1],1)
    std = std.to(device)
    mn = WholeSet.mn.repeat(x.shape[0],x.shape[1],1)
    mn = mn.to(device)
    rg = WholeSet.range.repeat(x.shape[0],x.shape[1],1)
    rg = rg.to(device)
    print(input_x.shape)
    input_return = (input_x*(rg*std)+mn).detach().cpu()
    
    net_behavior = LSTM(1,5,256,2,67) 
    net_behavior.load_state_dict(torch.load('model/behavior_prediction_67.pth'))
    net_behavior.to(device)
    inputs = torch.from_numpy(input_return[:,:,:-1].detach().cpu().numpy().astype(np.float32)).to(device)
    inputs = inputs.view(-1,inputs.shape[2]).unsqueeze(2)
    h = net_behavior.init_hidden(inputs.shape[0])
    h = tuple([each.data for each in h])
    behavior,h = net_behavior(inputs,h)
    _, class_ = torch.max(behavior, dim=1)
    class_ = torch.from_numpy(class_.detach().cpu().numpy().astype(np.double)).to(device)
    class_ = class_.view(x.shape[0],x.shape[1],-1)
    std = std[:,:,-1].unsqueeze(2)
    rg = rg[:,:,-1].unsqueeze(2)
    mn = mn[:,:,-1].unsqueeze(2)
    class_ = (class_ -mn) / (std*rg)
    py = torch.cat((input_x[:,:,:-1],class_),2)
    return py

# %%
x, y= test_iter.next()
x,y = x.to(device),y.to(device)
print(x[:,:,-1])
print(compute_label(x)[:,:,-1])
# Out:
# tensor([[-0.3312, -0.3312, -0.3312,  ..., -0.3312, -0.3312, -0.3312],
#         [-0.3312, -0.3312, -0.3312,  ..., -0.3312, -0.3312, -0.3312],
#         [ 1.1574,  1.1574,  1.1574,  ...,  1.1574,  1.1574,  1.1574],
#         ...,
#         [-0.3312, -0.3312, -0.3312,  ..., -0.3312, -0.3312, -0.3312],
#         [-0.3312, -0.3312, -0.3312,  ...,  1.1574,  1.1574,  1.1574],
#         [-0.3312, -0.3312, -0.3312,  ..., -0.3312, -0.3312, -0.3312]],
#        device='cuda:0', dtype=torch.float64)
# torch.Size([128, 100, 68])
# tensor([[-0.3312,  4.1346,  4.1346,  ..., -0.3312,  1.1574, -0.3312],
#         [ 4.1346,  4.1346,  4.1346,  ...,  4.1346,  4.1346,  4.1346],
#         [ 1.1574,  1.1574,  1.1574,  ...,  1.1574,  1.1574,  1.1574],
#         ...,
#         [ 2.6460,  2.6460,  2.6460,  ...,  2.6460,  2.6460,  2.6460],
#         [ 2.6460,  2.6460,  1.1574,  ...,  1.1574,  1.1574,  1.1574],
#         [ 4.1346,  4.1346,  4.1346,  ...,  4.1346,  4.1346,  4.1346]],
#        device='cuda:0', dtype=torch.float64)

# %%
def predict_trajectory_behavior(model,n):
    test = iter(Test)
    x,y =  test.next()
    x,y = x.to(device),y.to(device)
    x = compute_label(x)
    predY = model(x)
    criterion = nn.MSELoss()
    test_loss = criterion(predY,y)
    std = WholeSet.std.repeat(x.shape[0],x.shape[1],1)
    std = std[:,:,:4].to(device)
    mn = WholeSet.mn.repeat(x.shape[0],x.shape[1],1)
    mn = mn[:,:,:4].to(device)
    rg = WholeSet.range.repeat(x.shape[0],x.shape[1],1)
    rg = rg[:,:,:4].to(device)
    predY = (predY*(rg*std)+mn).detach().cpu()
    pY = np.array(predY)
    pY =  scipy.signal.savgol_filter(pY, window_length=31, polyorder=3,axis=1)
    local_labels = (y*(rg*std)+mn).detach().cpu()
    Y = np.array(local_labels)
    pY[:,:-predict_length,:] = Y[:,:-predict_length,:]
    rst_xy = calcu_XY(pY)
    rst_xy =  scipy.signal.savgol_filter(rst_xy, window_length=31, polyorder=3,axis=1)
   # rst_xy[:,-30:-1,:]=  scipy.signal.savgol_filter(rst_xy[:,-30:-1,:], window_length=51, polyorder=3,axis=0)
    plt.plot(rst_xy[:n,:,0][0],rst_xy[:n,:,1][0],'b',label="rst_xy")
  #  plt.plot(pY[:n,:,2][0],pY[:n,:,3][0],'r',label='prediction')
    plt.plot(Y[:n,:,2][0],Y[:n,:,3][0],'g',label='actual')
    plt.legend()
    print("Test Loss:",test_loss.item())
    
predict_trajectory_behavior(Prednet,1)
# Out:
# torch.Size([128, 100, 68])
# Test Loss: 0.038236458934425
